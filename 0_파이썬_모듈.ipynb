# %% [markdown]
# <a href="https://colab.research.google.com/github/wb0819111-prog/data_analysis/blob/main/0_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%AA%A8%EB%93%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 코랩을 이용하는 목적? 환경이 만들어져 있음, 정리,보기 편하다
#

# %%
# 모듈 => 내가 개발을 할 건데 그거에 도움을 줄 수 있는 것 ex) numpy/py파일로 만들어야아함

# %% [markdown]
# #**1. 파일 종류 소개**
# 파이썬에서는 .ipynb 파일과 .py 파일 모두 파이썬 코드를 작성할 수 있지만, 사용 목적과 형식이 다릅니다.
#
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FdrIfzo%2FbtsNXXAs4OR%2FAAAAAAAAAAAAAAAAAAAAAKXuY-Nk2RM2WOnAirwaQfRsOIuU9d0p1hVXF51Jkx5U%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1764514799%26allow_ip%3D%26allow_referer%3D%26signature%3DQzn%252B18eHDU3yyVv%252BVTeV8qPsU%252B8%253D'>

# %%
# .py파일 - 텍스트로 된 순수 파이썬 코드만 들어있다

# %% [markdown]
# #**2. 모듈**
# 파이썬에서 모듈을 만들려면 간단히 .py 확장자를 가진 파일에 코드를 작성하면 됩니다. 모듈은 단순한 함수 뿐만 아니라 변수, 클래스 등도 포함할 수 있으며, 다른 스크립트에서 import 구문을 사용하여 가져올 수 있습니다.

# %%
#py확장자 사용하여 사용/ 여기 코랩은 ipy 그래서 하나의 툴을 추가
# vsCode다운로드=> 얘는 기능없음,  가볍게 개발할 수 있게끔 환경만 만들어줌
# 필요한 것들을 다운로드 받아서 설치하면 이 툴 자체가 특정언어를 사용할 수 있게 된다
# 우리는 그래서 vsCode를 다운받아서 파이썬을 작동할 수 있도록 만든다

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# vsCode
# 단축기 만들기 -File -> Preference -> Keyboard shortcuts -> python run 검색 -> Python: Run Python File 클릭 -> 단축키 눌르면서 설정 -> Enter하면 등록

# %%
# VSCODE에서 우리가 만든 py파일을 여기 코랩에 올려줄 것이다
# 파일창 클릭 -> 코랩파일(ipy) -> c드라브에 우리가 만든 modul파일에 있는 math_tools.py를 드래그해서 파일창에 넣어줌

# %%
# 가져다쓰기        #import 파일명
import math_tools  # 파일 안에 변수,함수,클래스를 메모리에 올라가게함

# %%
math_tools.PI
# Out:
# 3.141592653589793

# %%
print(math_tools.add(5, 3))
print(math_tools.subtract(5, 3))
# Out:
# 8
# 2

# %%
circle = math_tools.Circle(5)
#원래는 circle = Circle(5) 이렇게 객체 생성하는데
# math_tools에서 가져왔기 때문에 math_tools.Circle(5) 로 객체 생성한다
print(circle.area())
# Out:
# 78.53981633974483

# %%
from math_tools import PI, Circle #math_tools 여기 안에 있는 PI, Circle하면
# 그대로 이름 가지고 쓸수 있다

# %%
print(PI)
circle = Circle(5)
print(circle.area())
# 이렇게 하면 이름만 불러다가 쓸 수 있다
# Out:
# 3.141592653589793
# 78.53981633974483

# %%
# as mt => 별명 mt
import math_tools as mt

# %%
print(mt.PI)
print(mt.add(5, 3))
print(mt.subtract(5, 3))
circle = Circle(5)
print(circle.area())
# Out:
# 3.141592653589793
# 8
# 2
# 78.53981633974483

# %%
# 그냥 파일창에다가 띄어놓고 하면 시간지나면 사라져서 계속 업로드해야하는 단점이 있다
# 그래서 구글 드라이브에다가 데이터,모듈를 올려놓고 끌어다가 import 하자  그러면 구글드라이브는 없어질 일 없으니까

# %%
# ex) import time 은 이렇게 하면 바로 쓸수 있다
# 왜냐하면 다른사람이 만든 것이 아니라 파이썬 개발자들이 만들어 놓은 것
# 메모리에 올려가 있지 않지만 파이썬환경에 py파일로 저장을 되어있다라는 의미
# 그래서 필요할때마다 import 해주면 그때그때 메모리에 올리겠다는 의미
# import하면 파이썬이 설치되어있는 폴더로 가서 이런 time.py를 찾는다 그거를 메모리에 올린다
# 즉, time은 파이썬에 설치되어있는 폴더에 있고 그거를 바로 import로 해서 불러올 수 있다

# 근데 구글드라이브에다가 math_tools.py파일을 import math_tools하면 찾을 수 없다
# 왜? 기본적으로 파이썬이 저장되어 있는 것만 찾기 때문에
# 따라서 우리는
# 구글 드라이브에 있는 module사용하기

# %%
# 구글 드라이브에 있는 module사용하기
# 구글드라이브 파일 경로복사
path = '/content/drive/MyDrive/AI활용 멀티모달 MCP PJ 시즌1/2. 데이터 분석/module' #경로 넣어줌

import sys   #시스템 모듈안에
# print(sys.path)   #여러경로나옴 => 앞으로 import하면 이경로로해서 찾거나 시스템적으로 등록되어 있는 파일
# 그래서 위에 있는 경로를 추가하게 되면 앞으로 import를 하게 되었을 때 import 경로에서 py파일을 찾을 수 있음

#추가하기
sys.path.append(path) # 추가하였으므로 앞으로 import경로에서 구글드라이브엥 있는 등록된 파일을 찾아 줄 수 있다

# %%
from math_tools import PI, Circle

print(PI)
circle = Circle(5)
print(circle.area())
# Out:
# 3.141592653589793
# 78.53981633974483

# %% [markdown]
# #**3. 패키지**
# 파이썬에서 패키지는 모듈들을 포함하고 있는 디렉터리입니다. 모듈은 파이썬 코드를 담고 있는 파일이며, 여러 모듈을 논리적으로 그룹화하려는 경우 패키지를 사용합니다. 패키지를 사용하면 관련된 기능들을 함께 묶어서 코드를 더욱 체계적으로 관리할 수 있습니다.
#
# ```
# my_package/    #폴더
# │
# ├── __init__.py  #파일
# │
# ├── module_a.py   #파일
# │
# └── sub_package/   #폴더
#     │
#     ├── __init__.py  #파일
#     └── module_b.py   #파일
#
# ```
#
# 패키지는 기본적으로 디렉터리와 그 안의 .py 파일들로 구성됩니다. 패키지를 구성하는 디렉터리 내에는 \_\_init\_\_.py라는 특별한 파일이 있어야 합니다. 이 파일은 해당 디렉터리가 파이썬 패키지임을 나타냅니다. \_\_init\_\_.py는 비워둘 수도 있고, 패키지 초기화 코드를 포함할 수도 있습니다. 또한 패키지 안에 다른 패키지(하위 패키지)를 포함할 수 있습니다. 이를 통해 복잡한 프로젝트의 코드를 여러 레벨의 디렉터리로 계층적으로 구성할 수 있습니다.

# %%
###########################위에 표참고
from my_package import module_a
from my_package.sub_package import module_b

# %%
# 규모가 있는 모듈, 파일이 여러개 있는 폴더로 구성되어 제공 =패키지  ex)numpy, pandas

# %% [markdown]
# ### 패키지 만들기 실습
# ```
# shapes/
# │
# ├── __init__.py
# ├── circle.py
# └── rectangle.py
# ```

# %%
#vsCode

# %%
# from shapes import * => 여기 있는 거 다가져와 하면
# __init__.py 파일에 등록되어있는 것을 다 가져온다 => *를 썼을 때 다 가져오고자 하는 것들을 __Init__.py에 등록한다
# packge에 초기화 파일 = __init__.py => 초기화 시켜주는 파일 ##################################################

# 1. 아래 코드를 작성하여 __init__.py 로 저장합니다.

# 기본적으로 패키지의 초기화 코드를 포함할 수 있습니다. 예를 들어, 패키지가 import 될 때 특정 변수를 설정하거나 다른 초기화 작업을 수행하려면 __init__.py 파일에 해당 코드를 작성합니다.
# 또한, __init__.py 파일을 사용하여 패키지 레벨에서의 import를 제어할 수 있습니다. 예를 들어, from shapes import *를 했을 때 어떤 모듈이 import 될지 정의할 수 있습니다.
# 아래 설정은 from shapes import *를 사용할 때 circle와 rectangle 모듈만 가져온다는 것을 의미합니다.

# %%
from shapes import circle, rectangle

# %%
# circle 모듈의 함수 사용
print(circle.area(5))  # 원의 면적
print(circle.circumference(5))  # 원의 둘레

# rectangle 모듈의 함수 사용
print(rectangle.area(4, 6))  # 직사각형의 면적
print(rectangle.perimeter(4, 6))  # 직사각형의 둘레

# 이름으로 가져왔으니 circle.~~
# Out:
# 78.53981633974483
# 31.41592653589793
# 24
# 20

# %%
# 앞에 있는 모듈명 말고 함수 이름만 쓰고 싶다
# 근데 circle.area ,rectangle.area 두개 다 area충돌
# 따라서 아래와 같이 해준다
# 이름이 충돌날 경우
from shapes.circle import area as circle_area
from shapes.rectangle import area as rectangle_area

# %%
print(circle_area(5))  # 원의 면적
print(rectangle_area(4, 6))  # 직사각형의 면적
# Out:
# 78.53981633974483
# 24
