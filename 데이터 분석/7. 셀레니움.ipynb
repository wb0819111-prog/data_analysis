# %% [markdown]
# # **1. 셀레니움**
# 셀레니움은 웹 브라우저를 사람이 직접 조작하는 것처럼 자동으로 제어할 수 있게 해주는 웹 자동화 도구

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2025.11.12)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.5.0->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.7/9.7 MB 14.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.9/9.7 MB 20.4 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.7 MB 24.8 MB/s eta 0:00:01
#    --------------------- ------------------ 5.1/9.7 MB 27.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.7 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 30.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 26.9 MB/s eta 0:00:00
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
#    ---------------------------------------- 0.0/512.0 kB ? eta -:--:--
#    --------------------------------------- 512.0/512.0 kB 33.5 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, pysocks, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.38.0 sortedcontainers-2.4.0 trio-0.32.0 trio-websocket-0.12.2 wsproto-1.3.2
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()
driver.get('https://www.google.com')
search = driver.find_element("name", "q")
search.send_keys("날씨")
time.sleep(2)
search.send_keys(Keys.RETURN)

# %% [markdown]
# # **2. 네이버 웹툰 리뷰 크롤링**

# %% [markdown]
# ### XPATH
# HTML, XML 문서 안에서 특정 요소를 정확하게ㅐ 찾아가기 위한 경로 표현식

# %%
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()
driver.get('https://comic.naver.com/webtoon/detail?titleId=823195&no=172&week=wed')
time.sleep(2)

print("*** 베스트 댓글 ***")
# /html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/ul/li[1]
# /html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/ul/li[2]
# /html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/ul/li[3]
xpath = '/html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/ul/li'
best_comment_elements = driver.find_elements(By.XPATH, xpath)

for li in best_comment_elements:
    try:
        # //*[@id="wcc_root"]/section/ul/li[1]/div[1]/div[2]/div/p
        # //*[@id="wcc_root"]/section/ul/li[2]/div[1]/div[2]/div/p
        comment_p = li.find_element(By.XPATH, "./div[1]/div[2]/div/p")
        comment_text = comment_p.text.strip()
        print(comment_text)
        print("-" * 30)
    except Exception as e:
        print(e)
# Out:
# *** 베스트 댓글 ***
# BEST본인들도 힘들었던 적이 있어서. 저런 순간에 저런 사소한 도움을 바랐던 적이 있었을테니까.....
# ------------------------------
# BEST미쳤다 진짜 따수운 세상이야 아직
# ------------------------------
# BEST이 웹툰 꼭 보셨으면.. 자기의 작은 친절이 한 사람 살린거임
# ------------------------------
# BEST저렇게 뚝딱거리는건 찐으로 도와주는거라고ㅜㅠㅠㅠㅠㅠㅠ
# ------------------------------
# BEST눙물.. 요즘 7개월 첫아이 육아때문에 지쳐서 맨날 우울해맀었는데 저도 비슷한 경험 많아요 ㅠㅠ
# 유모차 끌고 대학병원 갔을때 계단밖에 없는 구간에서 혼자라 멈칫했는데 아빠뻘 아저씨랑 아주머니랑 또래 여자분 셋이 유모차도 같이 들어주시고
# 얼마전에는 넘 지쳐서 울면서 아기안고 정처 없이 걷는데 고생한다고 토닥여주던 분들도 있었어요 ㅠㅠ
# 아직 세상은 너무 따뜻한거 같아요..!
# 다들 화이팅해요 ㅠ
# ------------------------------
# BEST이런 거 보면 진짜 사이비가 사회에 독을 푼거임 호의를 의심하게 됨 그러니 다 꺼져버려
# ------------------------------
# BEST세상이 참 신기... 사람한테 상처받고 사람한테 치유받음
# ------------------------------
# BEST이거 뭔지 알아...
# ------------------------------
# BEST진짜 따숩다...❤❤
# ------------------------------
# BEST???: 따... 딱히... 너를 위해 씌워준 게 아니라굿~!
# ------------------------------
# BEST그와중엨ㅎㅋㅎㅋㅎㅋ 밸런스 패칰ㅎㅋㅎㅋㅎㅋㅎ똑바로 하라곸ㅎㅋㅎㅋ
# ------------------------------
# BEST얼마전에 버스타고 병원가는데
# 어떤 여성분이 애기를 안고 버스를 타는 것임!
# 근데 자리가 없어서 내 앞에 서서 애기 달래시는데
# 굉장히 피곤해 보이셨음!!
# 난 공주니까 차칸일을 해야해! 생각하고
# 자리 양보하고 13정거장 서서갔엉
# 독초들아 나 착한일 했어!! 칭찬해죠🥰
# ------------------------------
# BEST혈색이 돌아왔다!! 분홍 쌉초ㅠㅠ 평생 꽃분홍빛깔만 가득해라ㅠㅠ
# ------------------------------
# BEST소나기는 그냥 내린거고, 어쩌다보니 그 자리에 여러분이 서 있었을 뿐이에요
# ------------------------------
# BEST다흐흑 인류애가 충전된다
# ------------------------------

# %%
# /html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/div[4]/button[2]
driver.find_element(By.XPATH, "/html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/div[4]/button[2]").click()
time.sleep(2)

# %%
print("*** 전체 댓글 ***")
xpath = '/html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/section/ul/li'
total_comment_elements = driver.find_elements(By.XPATH, xpath)

for li in total_comment_elements:
    try:
        comment_p = li.find_element(By.XPATH, "./div[1]/div[2]/div/p")
        comment_text = comment_p.text.strip()
        print(comment_text)
        print("-" * 30)
    except Exception as e:
        print(e)
# Out:
# *** 전체 댓글 ***
# 근데 엄청 안좋아 보였나보다
# ------------------------------
# ㅁㅈ우울증와서 죽어갈때 학원에서 화학쌤이 모르는문제 있냐고 물어보고 설명 친절하게 해주시고 나서 나도 누군가한테 대접받을 수 있는 존재라는걸 깨닫고 엄청 운다음에 정신차림
# ------------------------------
# 쌉초님 저 진짜진짜 너무 궁금해서 그러는데 자율복장회사 다니실때 룩 실존한건지 알고싶어요(사진이라든가...🥹
# ------------------------------
# 나도 100%사이비라고 생각함...
# 너무 많이 당했어 ㅂㄷㅂㄷ
# ------------------------------
# 묘하게 보라 그레이 핑크 쌉초
# ------------------------------
# 제가 우산이 되어드릴게요 부디 편히 쉬어주세요.. 아프지마 내 분홍 해파리..
# ------------------------------
# 쌉초님 이번 에피로 저도 힘들 때 도움 받았던 거 떠올라서 마음이 너무 따뜻해졌어요! 감사해요!!
# ------------------------------
# 저 처음 스타벅스에서 일할 때였는데 매장 쓰레기를 버리러 가고 있었거든요? 근데 너무 많이 가져왔는지 쓰레기 봉투가 수레에서 굴러 떨어지는 거예요... 이미 매장 밖이고 저 혼자 처리하기엔 너무 많아서 감당이 안되고 사실 일도 너무 힘들어서 버티고 있던 때거든요,, 너무 눈물 날 거 같은데, 스벅에서 음료 사서 나오시던 분이 도와주셨어요.... 사실 음료 사서 상큼하게 나오는데 쓰레기 봉투 만지기 싫으실 거잖아요. 막 괜찮다고 하는데도 본인도 괜찮으시다며 안정적이게 수레에 쌓아주시고 가셨어요.. 어둠 속에 있을 때 빛이 스치는 순간이 있는 거 같아요. 그분 진짜 하는 일 다 잘되셨으면 좋겠어요.
# ------------------------------
# 누구보다 빠르게 도와주고 퇴장ㅋㅋ
# ------------------------------
# 얼마나 짠해보였으면.. 짐을 들어주고 우산을 씌워주는 그대들 칭찬해
# ------------------------------
# 도움을 받았으니까 제사를 지내드려야겠네요.. 식사도 대접해드려야하고.
# ------------------------------
# 멀리까지가서 수박만 사시지..!! 미련
# ------------------------------
# 아 너무 이쁘다..
# ------------------------------
# 사람한테 데이고 정떨어지고해도 결국 또 다른사람 덕분에 인류애도 충전하고 힘이 나는거 같아요
# ------------------------------
# 아니 별일 맞는데요,, 이건 누구라도 울죠
# ------------------------------
# ㅜㅠ
# ------------------------------
# ㅜㅜㅡ 저거 진짜 맞음
# ------------------------------
# 그리고 이제 쌉초님이 우리를 행복하게 해주고 있어요! 항상 재밌게 보고 있어요
# 이렇게 힘든 시기를 이겨내고 다시 모니터 앞에서 그림그리고 있을 쌉초님 응원합니다
# ------------------------------
# 여자가 여자를 구한다 ㅠ
# ------------------------------
# 일하느라 번아웃 와서 알콜중독의 길로 빠졌을 때... 한 군데서 술을 많이 사면 이상하다고 생각할까 봐 온 동네 편의점 돌면서 술을 사모으는데 마지막으로 간 편의점 알바생이 괜찮으시냐고 물어본 적이 있다... 길고 긴 터널을 지나야 했지만 아직도 그 괜찮냐는 물음이 기억남. 지금은 술 끊은지 12년 됐다네요.
# ------------------------------

# %% [markdown]
# # **3. 픽사베이 이미지 크롤링**

# %%
from urllib.request import Request, urlopen

# %%
driver = webdriver.Chrome()
url = "https://pixabay.com/ko/images/search/강아지/"
driver.get(url)
