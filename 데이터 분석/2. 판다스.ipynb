# %% [markdown]
# #**1. 판다스(Pandas)**
# 판다스(Pandas)는 데이터 분석을 위한 파이썬 라이브러리 중 하나로, 표 형태의 데이터나 다양한 형태의 데이터를 쉽게 처리하고 분석할 수 있도록 도와주는 도구입니다. 주로 데이터프레임(DataFrame)이라는 자료구조를 제공하며, 이를 통해 테이블 형태의 데이터를 다루기 용이합니다.
#
# ```
# pip install pandas
# ```
# - 설치방법

# %%
# 판다스 메모리에 올림
import pandas as pd   #가져다쓰기

# %% [markdown]
# #**2. Series와 DataFrame**

# %% [markdown]
# ### 1. Series
#
# Series는 1차원 배열과 같은 자료구조로 하나의 열을 나타냅니다. 또한 각 요소는 인덱스(index)와 값(value)으로 구성되어 있습니다. 값은 넘파이의 ndarray 기반으로 저장됩니다. Series는 다양한 데이터 타입을 가질 수 있으며 정수, 실수, 문자열 등 다양한 형태의 데이터를 담을 수 있습니다.

# %%
# |   | 0(인덱스)<-인덱스객체
# |   | 1
# |   | 2
# |   | 3
# |   | 4
# |   | 5
# 상자 안에 들어가 있는 것은 value값
# 안에 들어있는 값은 ndarray기반으로 저장

# %%
idx = ['김사과', '반하나', '오렌지', '이메론', '배애리']
data = [67, 75, 90, 62, 98]

# pd.Series(데이터, 인덱스,데이터타입 ...) ###############################
# Series에 데이터를 넣어 만듦
pd.Series(data)  #옆에 있는것 인덱스,
# Out:
# 0    67
# 1    75
# 2    90
# 3    62
# 4    98
# dtype: int64

# %%
se1 = pd.Series(data, idx)
se1
#idx는 절대 중복되어선 안된다
# 67, 75, 90, 62, 98 => ndarray
# '김사과', '반하나', '오렌지', '이메론', '배애리 => index객체
# Out:
# 김사과    67
# 반하나    75
# 오렌지    90
# 이메론    62
# 배애리    98
# dtype: int64

# %%
print(se1.index)   # 판다스는 object타입이 있다 => 거의 99% str이라고 생각하면 된다######################/따로 판다스에는 str이 없다/인덱스객체
print(se1.values)
print(type(se1.values))  # ndarray############################
# Out:
# Index(['김사과', '반하나', '오렌지', '이메론', '배애리'], dtype='object')
# [67 75 90 62 98]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 2. DataFrame
#
# 데이터프레임(DataFrame)은 판다스(Pandas) 라이브러리에서 제공하는 중요하고 강력한 데이터 구조로, 2차원의 테이블 형태 데이터를 다루는 데 사용됩니다. 또한 각 요소는 인덱스(index), 열(column), 값(value)으로 구성되어 있습니다. 데이터프레임은 행과 열로 이루어져 있으며, 각 열은 다양한 데이터 타입을 가질 수 있습니다. 값은 넘파이의 ndarray 기반으로 저장됩니다.

# %%
# 열이름 = column / index /value(ndarray) 2차원의 테이블 형태
# 시리즈와 비슷 =>데이터프레임은 시리즈의 모임이라고 생각하면 된다##############################################

# %%
data = [[67, 93, 91],  #2차원
        [75, 68, 96],
        [87, 81, 82],
        [62, 70, 75],
        [98, 56, 87]]

idx = ['김사과', '반하나', '오렌지', '이메론', '배애리']
col = ['국어', '영어', '수학']

# %%
# # pd.DataFrame(데이터, 인덱스, 컬럼, datatype ...)
pd.DataFrame(data)
# Out:
#     0   1   2
# 0  67  93  91
# 1  75  68  96
# 2  87  81  82
# 3  62  70  75
# 4  98  56  87

# %%
pd.DataFrame(data, idx)  #Serise처럼
# Out:
#       0   1   2
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
pd.DataFrame(data, idx, col)
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
df = pd.DataFrame(index=idx, columns=col, data=data)
df #print로 찍어도 되지만 못생기게 나온다
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  87  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %%
print(df.index)    #index객체
print(df.columns)  #index객체 ############################################3###
print(df.values)
# Out:
# Index(['김사과', '반하나', '오렌지', '이메론', '배애리'], dtype='object')
# Index(['국어', '영어', '수학'], dtype='object')
# [[67 93 91]
#  [75 68 96]
#  [87 81 82]
#  [62 70 75]
#  [98 56 87]]

# %%
# 딕셔너리를 사용하여 데이터프레임을 생성하기################################################
dic = {
    '국어':[67, 75, 76, 62, 98],
    '영어':[93, 68, 81, 70, 56],
    '수학':[91, 96, 82, 75, 87]
}

df = pd.DataFrame(data=dic, index=idx)
df
# Out:
#      국어  영어  수학
# 김사과  67  93  91
# 반하나  75  68  96
# 오렌지  76  81  82
# 이메론  62  70  75
# 배애리  98  56  87

# %% [markdown]
# ### 3. CSV 파일 읽어오기
# CSV 파일은 Comma-Separated Values(쉼표로 구분된 값) 파일의 약자로, 데이터를 단순한 텍스트 형식으로 저장하는 데 사용되는 파일 형식입니다

# %%
# 자료를 메모장으로 보면 , 로 데이터가 구분되어 있다 , 로 데이터를 구분하는 것
# CSV = 파일형식(형태)/쉼표로 구분된 값 ##############################################################################################

# %%
# 폴더의 경로가 아니고 파일 자체의 경로 복사

# %%
df = pd.read_csv('/content/drive/MyDrive/AI활용 멀티모달 MCP PJ 시즌1/2. 데이터 분석/data/idol.csv')
# 판다스에 read_csv() 라는 메소드가 있는데 얘가 csv가 있는 경로를 알려주면 그 csv를 갖다가 알아서 데이터프레임을 만들어준다

# 근데 왜 모듈은 폴더 경로를 쓰고 데이터는 파일경로를 쓸까? ###################################################################
# 모듈은 가져올 때는 "파일위치(경로)"가 아니라 파이썬 패키지 경로 사용 => import numpy.random
# 폴더 경로가 아니라 실제 파일의 위치를 그대로 적어줘야함 => pd.read.csv("경로링크")

# 어떤 모듈을 가져다 쓸 지 모르겠으니까 폴더 이름을 써주면 그 폴더 내에 있는 py파일들을 다 찾으라는 의미

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #**4. 데이터프레임 기본 정보 알아보기**

# %%
df.info()  #데이터 간략정보 보기/ RangeIndex: 20 entries =>20개 데이터/ Non-Null Count=>데이터가  비어있지 않은게 몇개인지/
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       20 non-null     object
#  1   그룹       20 non-null     object
#  2   소속사      19 non-null     object
#  3   성별       20 non-null     object
#  4   생년월일     20 non-null     object
#  5   키        19 non-null     float64
#  6   혈액형      19 non-null     object
#  7   브랜드평판지수  20 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ KB

# %%
df.columns
# Out:
# Index(['이름', '그룹', '소속사', '성별', '생년월일', '키', '혈액형', '브랜드평판지수'], dtype='object')

# %%
new_columns = ['name', 'group', 'company', 'gender', 'birthday', 'height', 'blood', 'brand']
df.columns = new_columns  #개수가 맞아야함
df
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
# describe(): 통계 정보를 반환 #숫자,넘버값에 대한 것만 빼온다#####################숫자에 관련된 정보만 가져온다
df.describe()
# Out:
#            height         brand
# count   19.000000  2.000000e+01
# mean   170.536842  2.700190e+06
# std      7.225204  1.381919e+06
# min    161.000000  1.680587e+06
# 25%    164.750000  1.887423e+06
# 50%    168.000000  2.074682e+06
# 75%    179.000000  2.623465e+06
# max    182.000000  6.267302e+06

# %%
df.describe(include=object) # Top: 최빈값, freq: 최빈값의 빈도 #################################################################
# unique	= 유일한값(똑같은게 없는)
# top = 가장 많이 포함되어 있는 값 (가장많이 겹쳐있는 것)
# freq = 최빈값 개수
# Out:
#        name  group company gender    birthday blood
# count    20     20      19     20          20    19
# unique   20      6       5      2          20     4
# top      지민  방탄소년단     빅히트     여자  1995-10-13     A
# freq      1      5       7     13           1    11

# %%
# 원하는 개수의 데이터 보기
df.head() # 상위 5개의 row를 출력
# Out:
#   name  group company gender    birthday  height blood    brand
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3   하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4    뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048

# %%
df.head(3) # 상위 3개의 row를 출력
# Out:
#   name  group company gender    birthday  height blood    brand
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081

# %%
df.tail() # 하위 5개의 row를 출력
# Out:
#     name  group company gender    birthday  height blood    brand
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587

# %%
df.tail(2) # 하위 2개의 row를 출력
# Out:
#     name  group company gender    birthday  height blood    brand
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587

# %%
# 정렬하기

df.sort_index() # index로 오름차순 정렬: 기본값
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
df.sort_index(ascending=False) # index로 내림차순 정렬#################################################
# Out:
#     name  group company gender    birthday  height blood    brand
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# ...

# %%
df.sort_values(by='height') # 키로 오름차순 정렬 ######################################################################
# Out:
#     name  group company gender    birthday  height blood    brand
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# ...

# %%
df.sort_values(by='height', ascending=False) # 키로 내림차순 정렬
# Out:
#     name  group company gender    birthday  height blood    brand
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# ...

# %%
# 키로 내림차순 정렬. NaN을 위로 올림


df.sort_values(by='height', ascending=False, na_position='first')
#####################################################
# Out:
#     name  group company gender    birthday  height blood    brand
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# ...

# %%
# 1차 정렬: 키(내림차순), 2차 정렬: 브랜드(내림차순) ###################################################
# 같은 것이 있을때 그것들로 2차 정렬 ###############################################################



df.sort_values(by=['height', 'brand'], ascending=[False, False], na_position='first')
#여러개를 묶을때는 리스트로 정렬한다
# 2차정렬 전에는 동일한 것이 있을 때 인덱스로 정렬된다
# Out:
#     name  group company gender    birthday  height blood    brand
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# ...

# %% [markdown]
# #**5. 데이터 다루기**

# %%
df.head()
# Out:
#   name  group company gender    birthday  height blood    brand
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3   하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4    뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048

# %%
df['blood'] #열만 가져오기
# Out:
# 0       A
# 1       A
# 2       A
# 3       O
# 4      AB
# 5     NaN
# 6       O
# 7       A
# 8       B
# 9       A
# 10      A
# 11      B
# 12      A
# 13      A
# 14      B
# 15      B
# 16      A
# 17      A
# 18      A
# 19      O
# Name: blood, dtype: object

# %%
type(df['blood']) #Series 타입#######################################################
# Out:
# pandas.core.series.Series

# %%
df.blood #객체 타입으로도 접근 가능
# Out:
# 0       A
# 1       A
# 2       A
# 3       O
# 4      AB
# 5     NaN
# 6       O
# 7       A
# 8       B
# 9       A
# 10      A
# 11      B
# 12      A
# 13      A
# 14      B
# 15      B
# 16      A
# 17      A
# 18      A
# 19      O
# Name: blood, dtype: object

# %%
df.head(3)
# Out:
#   name  group company gender    birthday  height blood    brand
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081

# %%
df[:3]
# Out:
#   name  group company gender    birthday  height blood    brand
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081

# %%
# loc 인덱싱: 컬럼 인덱싱 ###################################
df.loc[:, 'name'] # df['name']  #df.loc[:(행개수), 'name'(열이름)]/numpy는 sort(data)[열,행] 기준
# Out:
# 0       지민
# 1       정국
# 2       민지
# 3       하니
# 4        뷔
# 5      다니엘
# 6       혜인
# 7       지수
# 8       해린
# 9       태연
# 10      RM
# 11      제니
# 12     옹성우
# 13      리사
# 14      로제
# 15      윤아
# 16      조이
# 17      슬기
# 18    강다니엘
# 19       진
# Name: name, dtype: object

# %%
df.loc[2:5, 'name'] # 5번을 포함###########################################################
# Out:
# 2     민지
# 3     하니
# 4      뷔
# 5    다니엘
# Name: name, dtype: object

# %%
df.loc[2:5, ['name', 'gender', 'height']]  #데이터 묶어줌
# Out:
#   name gender  height
# 2   민지     여자   169.0
# 3   하니     여자   161.7
# 4    뷔     남자   179.0
# 5  다니엘     여자   165.0

# %%
df.loc[2:5, 'name' : 'height']  #범위를 줘서 가능 (슬라이싱으로도 가능)
# Out:
#   name  group company gender    birthday  height
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0
# 3   하니    뉴진스     어도어     여자  2004-10-06   161.7
# 4    뷔  방탄소년단     빅히트     남자  1995-12-30   179.0
# 5  다니엘    뉴진스     어도어     여자  2005-04-11   165.0

# %%
df.loc[[2,5], ['name', 'gender', 'height']]
# Out:
#   name gender  height
# 2   민지     여자   169.0
# 5  다니엘     여자   165.0

# %%
# iloc 인덱싱: index로 인덱싱 ############################## index + loc#########################
df.iloc[:, 0] #df.iloc[:(모든행), 0(0번 열)]
# Out:
# 0       지민
# 1       정국
# 2       민지
# 3       하니
# 4        뷔
# 5      다니엘
# 6       혜인
# 7       지수
# 8       해린
# 9       태연
# 10      RM
# 11      제니
# 12     옹성우
# 13      리사
# 14      로제
# 15      윤아
# 16      조이
# 17      슬기
# 18    강다니엘
# 19       진
# Name: name, dtype: object

# %%
df.iloc[:, 0:3] # 3을 포함하지 않음 ###################################### loc는 포함한다
# Out:
#     name  group company
# 0     지민  방탄소년단     빅히트
# 1     정국  방탄소년단     빅히트
# 2     민지    뉴진스     어도어
# 3     하니    뉴진스     어도어
# 4      뷔  방탄소년단     빅히트
# 5    다니엘    뉴진스     어도어
# 6     혜인    뉴진스     어도어
# 7     지수   블랙핑크     와이지
# 8     해린    뉴진스     어도어
# 9     태연   소녀시대     에스엠
# 10    RM  방탄소년단     빅히트
# 11    제니   블랙핑크     와이지
# 12   옹성우    워너원    판타지오
# 13    리사   블랙핑크     와이지
# 14    로제   블랙핑크     와이지
# 15    윤아   소녀시대     에스엠
# 16    조이   레드벨벳     빅히트
# 17    슬기   레드벨벳     빅히트
# 18  강다니엘    워너원     NaN
# 19     진  방탄소년단     빅히트

# %%
df.iloc[1:5, 0:2]  #포함하지않음 => iloc
# Out:
#   name  group
# 1   정국  방탄소년단
# 2   민지    뉴진스
# 3   하니    뉴진스
# 4    뷔  방탄소년단

# %%
df['height'] >= 180
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: height, dtype: bool

# %%
df[df['height'] >= 180]  ###############################################??????????????????????????
# [df['height'] >= 180] 이거를 실제 데이터프레임에 다시 넣어주면 True인값만 나온다
# Out:
#     name  group company gender    birthday  height blood    brand
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444

# %%
df[df['height'] >= 180]['name'] # df['name'][df['height'] >= 180]
# Out:
# 10      RM
# 18    강다니엘
# Name: name, dtype: object

# %%
df['name'][df['height'] >= 180]
# Out:
# 10      RM
# 18    강다니엘
# Name: name, dtype: object

# %%
df[df['height'] >= 180][['name', 'gender', 'height']]
# Out:
#     name gender  height
# 10    RM     남자   181.0
# 18  강다니엘     남자   182.0

# %%
# loc를 이용해서 뽑아오기
df.loc[df['height'] >= 180, ['name', 'gender', 'height']] #행,열
# Out:
#     name gender  height
# 10    RM     남자   181.0
# 18  강다니엘     남자   182.0

# %%
df
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
#전체 company에서 빅히트, 어도어 존재하니 묻는 것



company = ['빅히트', '어도어']
df['company'].isin(company) #전체 company에서 빅히트, 어도어 존재하니 묻는 것####################################################
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# Name: company, dtype: bool

# %%
# True인것만 보기


df[df['company'].isin(company)] # df.loc[df['company'].isin(company),:]
# Out:
#    name  group company gender    birthday  height blood    brand
# 0    지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1    정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2    민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3    하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4     뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5   다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6    혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 8    해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 10   RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 16   조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 17   슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767
# 19    진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587

# %%
#loc로 해보기


df.loc[df['company'].isin(company),:]  #loc는 안에 있는 조건을 작성한다###########################
# Out:
#    name  group company gender    birthday  height blood    brand
# 0    지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1    정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2    민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3    하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4     뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5   다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6    혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 8    해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 10   RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 16   조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514
# 17   슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767
# 19    진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587

# %% [markdown]
# #**6. 결측값**
# 결측값은 값이 누락된 데이터를 의미하며, 판다스에서는 일반적으로 NaN으로 표시됩니다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     object
#  1   group     20 non-null     object
#  2   company   19 non-null     object
#  3   gender    20 non-null     object
#  4   birthday  20 non-null     object
#  5   height    19 non-null     float64
#  6   blood     19 non-null     object
#  7   brand     20 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ KB

# %%
df #NaN찾기
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
df.isna()  # 너 혹시 Na값이니? => True, False
# Out:
#      name  group  company  gender  birthday  height  blood  brand
# 0   False  False    False   False     False   False  False  False
# 1   False  False    False   False     False   False  False  False
# 2   False  False    False   False     False   False  False  False
# 3   False  False    False   False     False   False  False  False
# 4   False  False    False   False     False   False  False  False
# 5   False  False    False   False     False   False   True  False
# 6   False  False    False   False     False   False  False  False
# 7   False  False    False   False     False   False  False  False
# 8   False  False    False   False     False   False  False  False
# 9   False  False    False   False     False    True  False  False
# 10  False  False    False   False     False   False  False  False
# 11  False  False    False   False     False   False  False  False
# 12  False  False    False   False     False   False  False  False
# ...

# %%
df.isnull() ## 너 혹시 Na값이니? => True, False########################
# Out:
#      name  group  company  gender  birthday  height  blood  brand
# 0   False  False    False   False     False   False  False  False
# 1   False  False    False   False     False   False  False  False
# 2   False  False    False   False     False   False  False  False
# 3   False  False    False   False     False   False  False  False
# 4   False  False    False   False     False   False  False  False
# 5   False  False    False   False     False   False   True  False
# 6   False  False    False   False     False   False  False  False
# 7   False  False    False   False     False   False  False  False
# 8   False  False    False   False     False   False  False  False
# 9   False  False    False   False     False    True  False  False
# 10  False  False    False   False     False   False  False  False
# 11  False  False    False   False     False   False  False  False
# 12  False  False    False   False     False   False  False  False
# ...

# %%
# 결측지가 아닌 것을 True로 하고싶어################################################
df.notnull()
# Out:
#     name  group  company  gender  birthday  height  blood  brand
# 0   True   True     True    True      True    True   True   True
# 1   True   True     True    True      True    True   True   True
# 2   True   True     True    True      True    True   True   True
# 3   True   True     True    True      True    True   True   True
# 4   True   True     True    True      True    True   True   True
# 5   True   True     True    True      True    True  False   True
# 6   True   True     True    True      True    True   True   True
# 7   True   True     True    True      True    True   True   True
# 8   True   True     True    True      True    True   True   True
# 9   True   True     True    True      True   False   True   True
# 10  True   True     True    True      True    True   True   True
# 11  True   True     True    True      True    True   True   True
# 12  True   True     True    True      True    True   True   True
# ...

# %%
# 하나의 Series에서 Na값 확인하기
df['height'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: height, dtype: bool

# %%
# NA인 데이터만 보기 ###################################################

df[df['height'].isna()]
# Out:
#   name group company gender    birthday  height blood    brand
# 9   태연  소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866

# %%
# Na인데 다른 정보말고 이름만 보고싶어

df[df['height'].isna()]['name']
# Out:
# 9    태연
# Name: name, dtype: object

# %%
df[df['height'].notnull()]
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# ...

# %%
################################################### =df[df['height'].notnull()] 같은말



df[~df['height'].isnull()]
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# ...

# %%
# df.loc[행 조건, 열 조건]


df.loc[df['company'].notnull(), ['name', 'company', 'group', 'gender']]
# df.loc[행 조건, 열 조건]  ###############################################################
# Out:
#    name company  group gender
# 0    지민     빅히트  방탄소년단     남자
# 1    정국     빅히트  방탄소년단     남자
# 2    민지     어도어    뉴진스     여자
# 3    하니     어도어    뉴진스     여자
# 4     뷔     빅히트  방탄소년단     남자
# 5   다니엘     어도어    뉴진스     여자
# 6    혜인     어도어    뉴진스     여자
# 7    지수     와이지   블랙핑크     여자
# 8    해린     어도어    뉴진스     여자
# 9    태연     에스엠   소녀시대     여자
# 10   RM     빅히트  방탄소년단     남자
# 11   제니     와이지   블랙핑크     여자
# 12  옹성우    판타지오    워너원     남자
# 13   리사     와이지   블랙핑크     여자
# 14   로제     와이지   블랙핑크     여자
# 15   윤아     에스엠   소녀시대     여자
# 16   조이     빅히트   레드벨벳     여자
# 17   슬기     빅히트   레드벨벳     여자
# 19    진     빅히트  방탄소년단     남자

# %%
# 학습하거나 등등 그런 모델에 데이터를 넣을 때 무조건 다 숫자화 시켜야한다
# 기계는 일단 문자를 못 알아 먹기때문에 다 숫자로 바꿔야 한다
# 그리고 데이터가 비어있는게 있으면 안된다 (결측치 제거 필요)
# 그래야 정상적으로 학습된다
# 근데 결측치가 많아 다 삭제해버리면 남는 데이터가 얼마 없다 그러면 학습시킬 수 없다 너무 데이터가 없어서
# 학습시킬려면 충분한,많은 데이터가 필요하다
# 얄,질의 데이터 필요/ 너무 지우면 손실이 크니까 결측값을 평균값,최빈값,대체값을 넣는 방법도 있다

# %%
df['height']
# Out:
# 0     174.0
# 1     179.0
# 2     169.0
# 3     161.7
# 4     179.0
# 5     165.0
# 6     170.0
# 7     162.0
# 8     164.5
# 9       NaN
# 10    181.0
# 11    163.0
# 12    179.0
# 13    167.0
# 14    168.0
# 15    168.0
# 16    168.0
# 17    161.0
# 18    182.0
# 19    179.0
# Name: height, dtype: float64

# %%
# fillna(): 결측값을 채워주는 함수
df['height'].fillna(0) # df['height].fillna(0, inplace=True) 적용 =>  nplace=True 값을 적용 원본 바뀜###########################
# Out:
# 0     174.0
# 1     179.0
# 2     169.0
# 3     161.7
# 4     179.0
# 5     165.0
# 6     170.0
# 7     162.0
# 8     164.5
# 9       0.0
# 10    181.0
# 11    163.0
# 12    179.0
# 13    167.0
# 14    168.0
# 15    168.0
# 16    168.0
# 17    161.0
# 18    182.0
# 19    179.0
# Name: height, dtype: float64

# %%
df['height']
# Out:
# 0     174.0
# 1     179.0
# 2     169.0
# 3     161.7
# 4     179.0
# 5     165.0
# 6     170.0
# 7     162.0
# 8     164.5
# 9       NaN
# 10    181.0
# 11    163.0
# 12    179.0
# 13    167.0
# 14    168.0
# 15    168.0
# 16    168.0
# 17    161.0
# 18    182.0
# 19    179.0
# Name: height, dtype: float64

# %%
df_copy = df.copy()   # 복사하기
df_copy
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
height = df_copy['height'].mean()
height
# Out:
# np.float64(170.53684210526316)

# %%
# 복사본에 평균값 채워보기


df_copy['height'] = df_copy['height'].fillna(height)
df_copy['height']
# Out:
# 0     174.000000
# 1     179.000000
# 2     169.000000
# 3     161.700000
# 4     179.000000
# 5     165.000000
# 6     170.000000
# 7     162.000000
# 8     164.500000
# 9     170.536842
# 10    181.000000
# 11    163.000000
# 12    179.000000
# 13    167.000000
# 14    168.000000
# 15    168.000000
# 16    168.000000
# 17    161.000000
# 18    182.000000
# 19    179.000000
# Name: height, dtype: float64

# %%
df_copy = df.copy()  #깨끗하게 다시 하기 위해 다시 copy / NAN
df_copy['height']
# Out:
# 0     174.0
# 1     179.0
# 2     169.0
# 3     161.7
# 4     179.0
# 5     165.0
# 6     170.0
# 7     162.0
# 8     164.5
# 9       NaN
# 10    181.0
# 11    163.0
# 12    179.0
# 13    167.0
# 14    168.0
# 15    168.0
# 16    168.0
# 17    161.0
# 18    182.0
# 19    179.0
# Name: height, dtype: float64

# %%
height = df_copy['height'].median() # 50%값, 중위
height
# Out:
# 168.0

# %%
# 중앙값 넣기, 원본 변경


df_copy['height'].fillna(height, inplace=True) #아예 저장
df_copy['height']
# Out:
# 0     174.0
# 1     179.0
# 2     169.0
# 3     161.7
# 4     179.0
# 5     165.0
# 6     170.0
# 7     162.0
# 8     164.5
# 9     168.0
# 10    181.0
# 11    163.0
# 12    179.0
# 13    167.0
# 14    168.0
# 15    168.0
# 16    168.0
# 17    161.0
# 18    182.0
# 19    179.0
# Name: height, dtype: float64

# %%
df_copy = df.copy()
df_copy
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
# dropna(): 결측값이 있는 행 또는 열을 모두 제거. 결측값이 한개라도 있는 경우 삭제
# 기본값 axis=0 (행 삭제)


df_copy.dropna() #5,9,18삭제됨
# numpy이는 axis=0 일때 열로 연산한다/ pandas는 axis=0 일때 행###############################
# Out:
#    name  group company gender    birthday  height blood    brand
# 0    지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1    정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2    민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3    하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4     뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 6    혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7    지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8    해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 10   RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11   제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12  옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# 13   리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800
# 14   로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132
# ...

# %%
# 열제거

df_copy.dropna(axis=1) # 결측값이 있는 열을 제거 (company, height,boold)
# Out:
#     name  group gender    birthday    brand
# 0     지민  방탄소년단     남자  1995-10-13  6267302
# 1     정국  방탄소년단     남자  1997-09-01  5805844
# 2     민지    뉴진스     여자  2004-05-07  4437081
# 3     하니    뉴진스     여자  2004-10-06  4161153
# 4      뷔  방탄소년단     남자  1995-12-30  3470048
# 5    다니엘    뉴진스     여자  2005-04-11  2341271
# 6     혜인    뉴진스     여자  2008-04-21  2301785
# 7     지수   블랙핑크     여자  1995-01-03  2227460
# 8     해린    뉴진스     여자  2006-05-15  2173376
# 9     태연   소녀시대     여자  1989-03-09  2079866
# 10    RM  방탄소년단     남자  1994-09-12  2069499
# 11    제니   블랙핑크     여자  1996-01-16  2069250
# 12   옹성우    워너원     남자  1995-08-25  1954327
# 13    리사   블랙핑크     여자  1997-03-27  1912800
# 14    로제   블랙핑크     여자  1997-02-11  1888132
# 15    윤아   소녀시대     여자  1990-05-30  1885297
# 16    조이   레드벨벳     여자  1996-09-03  1830514
# 17    슬기   레드벨벳     여자  1994-02-10  1741767
# 18  강다니엘    워너원     남자  1996-12-10  1706444
# 19     진  방탄소년단     남자  1992-12-04  1680587

# %% [markdown]
# ###※ axis
#
# 1. NumPy는 수학적 배열 연산에서 출발했기 때문에, 축(axis) 개념이 배열의 모양과 연산 방향에 초점을 맞춥니다.
#
# - axis=0: 배열의 세로 방향(열), axis=1: 배열의 가로 방향(행)
#
#
#
# 2. Pandas는 데이터 분석에 특화된 라이브러리로, 행(row)과 열(column)을 명시적으로 구분하여 작업을 수행합니다.
#
# - axis=0: 행(row)을 대상으로 작업(열 간 연산). axis=1: 열(column)을 대상으로 작업(행 간 연산)

# %%
#데이터 프레임 열 하나는 => Series /그 여러 Series모이면 데이터 프레임

# %% [markdown]
# #**7. 행, 열 추가 및 삭제하기**

# %%
df_copy = df.copy() #원본복사
df_copy
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
dic = {
    'name': '김사과',
    'group': '과수원',
    'company': '애플',
    'gender': '여자',
    'birthday': '2000-01-01',
    'height': 160.0,
    'blood': 'A',
    'brand': 1234567
}

# %%
# 추가하기



# concat(): 데이터를 합침. axis=0 (기본값)
df_copy = pd.concat([df_copy, pd.DataFrame(dic, index=[0])], ignore_index=True) #ignore_index=True => 인덱스를 True로해서 데이터프레임의 번호 다음으로 붙여준다 차례대로 인덱스 재정렬
df_copy
#pd.DataFrame(dic, index=[0]) => 하나의 행을 데이터프레임화 시키겠다는 의미#########################ignore_index=True 정렬을 해주는게 좋다 아니면 따로 놀게 된다 별개로 20 이 두개 생김
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
pd.concat([df_copy, pd.DataFrame(dic, index=[0])])
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
df_copy['nation'] = '대한민국' # nation 없으므로 추가가 된다 모든사람
df_copy.head()
# Out:
#   name  group company gender    birthday  height blood    brand nation
# 0   지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302   대한민국
# 1   정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844   대한민국
# 2   민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081   대한민국
# 3   하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153   대한민국
# 4    뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048   대한민국

# %%
df_copy.tail()
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514   대한민국
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767   대한민국
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444   대한민국
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587   대한민국
# 20   김사과    과수원      애플     여자  2000-01-01   160.0     A  1234567   대한민국

# %%
df_copy.loc[df_copy['name'] == '김사과']
# Out:
#    name group company gender    birthday  height blood    brand nation
# 20  김사과   과수원      애플     여자  2000-01-01   160.0     A  1234567   대한민국

# %%
df_copy.loc[df_copy['name'] == '김사과', 'nation']
# Out:
# 20    대한민국
# Name: nation, dtype: object

# %%
df_copy.loc[df_copy['name'] == '김사과', 'nation'] = '미국' #?????????????????????????????????
df_copy.tail()
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514   대한민국
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767   대한민국
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444   대한민국
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587   대한민국
# 20   김사과    과수원      애플     여자  2000-01-01   160.0     A  1234567     미국

# %%
# 행 제거하기


df_copy.drop(20, axis=0) # 0: 행, 1: 열 # 20번 행 삭제, 적용된 건 아님
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302   대한민국
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844   대한민국
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081   대한민국
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153   대한민국
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048   대한민국
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271   대한민국
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785   대한민국
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460   대한민국
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376   대한민국
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866   대한민국
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499   대한민국
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250   대한민국
# ...

# %%
df_copy.tail()
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 16    조이   레드벨벳     빅히트     여자  1996-09-03   168.0     A  1830514   대한민국
# 17    슬기   레드벨벳     빅히트     여자  1994-02-10   161.0     A  1741767   대한민국
# 18  강다니엘    워너원     NaN     남자  1996-12-10   182.0     A  1706444   대한민국
# 19     진  방탄소년단     빅히트     남자  1992-12-04   179.0     O  1680587   대한민국
# 20   김사과    과수원      애플     여자  2000-01-01   160.0     A  1234567     미국

# %%
# 여러행 지우기


df_copy.drop([1, 3, 5, 7, 20], axis=0)   # 보여주기식만, 원본삭제X
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302   대한민국
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081   대한민국
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048   대한민국
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785   대한민국
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376   대한민국
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866   대한민국
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499   대한민국
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250   대한민국
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327   대한민국
# 13    리사   블랙핑크     와이지     여자  1997-03-27   167.0     A  1912800   대한민국
# 14    로제   블랙핑크     와이지     여자  1997-02-11   168.0     B  1888132   대한민국
# 15    윤아   소녀시대     에스엠     여자  1990-05-30   168.0     B  1885297   대한민국
# ...

# %%
# 열 제거하기


df_copy.drop('nation', axis=1)
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
df_copy.drop(['nation', 'group'], axis=1)
# Out:
#     name company gender    birthday  height blood    brand
# 0     지민     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    판타지오     남자  1995-08-25   179.0     A  1954327
# 13    리사     와이지     여자  1997-03-27   167.0     A  1912800
# 14    로제     와이지     여자  1997-02-11   168.0     B  1888132
# ...

# %% [markdown]
# #**8. 통계 함수**

# %%
df_copy.describe()
# Out:
#            height         brand
# count   20.000000  2.100000e+01
# mean   170.010000  2.630399e+06
# std      7.416688  1.384378e+06
# min    160.000000  1.234567e+06
# 25%    164.125000  1.885297e+06
# 50%    168.000000  2.069499e+06
# 75%    179.000000  2.341271e+06
# max    182.000000  6.267302e+06

# %%
#hieght 합계 하기


df_copy['height'].sum() # 합계
# Out:
# np.float64(3400.2)

# %%
df_copy['height'].count() # 개수, NaN은 포함하지 않음 #김사과까지 20명
# Out:
# np.int64(20)

# %%
df_copy['height'].mean() # 평균
# Out:
# np.float64(170.01)

# %%
df_copy['height'].median() # 중앙값
# Out:
# 168.0

# %% [markdown]
# ###※ 평균과 중앙값
#
# 평균은 모든 데이터를 더한 후, 데이터 개수로 나눈 값입니다. 데이터를 고르게 분배했을 때, 한 데이터가 가질 수 있는 이론적인 중심값을 의미합니다. 중앙값은 데이터를 크기 순서대로 정렬했을 때, 가운데 위치하는 값입니다. 데이터의 순서에만 영향을 받고, 값의 크기에는 영향을 받지 않습니다. 데이터가 고르게 분포된 경우 평균과 중앙값이 비슷하거나 같습니다. 하지만 데이터에 극단값(Outlier)이 있는 경우 평균은 극단값의 영향을 받아 왜곡될 수 있지만, 중앙값은 비교적 안정적입니다.

# %%
df_copy['height'].max() # 최대값
# Out:
# 182.0

# %%
df_copy['height'].min() # 최소값
# Out:
# 160.0

# %%
df_copy['height'].var() # 분산
# Out:
# 55.007263157894734

# %%
df_copy['height'].std() # 표준편차
# Out:
# 7.416688152935563

# %% [markdown]
# ###※ 분산과 표준편차
#
# 분산(Variance)과 표준편차(Standard Deviation)는 데이터가 평균에서 얼마나 퍼져 있는지를 나타내는 산포도(분포 정도)를 측정하는 지표입니다. 분산은 데이터가 평균을 기준으로 얼마나 퍼져 있는지를 나타냅니다. 평균에서 각 데이터의 거리를 제곱한 값들의 평균입니다. 표준편차는 분산의 제곱근입니다. 분산은 제곱 값이기 때문에 단위가 커질 수 있는데, 이를 원래 데이터와 같은 단위로 변환하기 위해 제곱근을 씌웁니다.
#
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FlSDKp%2FbtsLh5aU1e8%2FAAAAAAAAAAAAAAAAAAAAALLo-v9lCG02Pjz21LsA2v3fa3ieSoACoMfBNnkw9FCc%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1764514799%26allow_ip%3D%26allow_referer%3D%26signature%3D%252F%252FyoVoFTBwK9w9C3TykG0cuPFgQ%253D'>

# %%
# 표준편차는 값을 다운시키기 위해 있따 => 루트씌움

# %% [markdown]
# #**9. 그룹**

# %%
df_copy
# Out:
#     name  group company gender    birthday  height blood    brand nation
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302   대한민국
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844   대한민국
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081   대한민국
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153   대한민국
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048   대한민국
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271   대한민국
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785   대한민국
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460   대한민국
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376   대한민국
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866   대한민국
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499   대한민국
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250   대한민국
# ...

# %%
# groupby(): 데이터를 그룹으로 묶어 분석할 때 사용


df_copy.groupby('group') #이게 객체라는 것을 알 수 있따

# %%
# 그룹을 맺으면 통계함수를 사용할 수 있음


df_copy.groupby('group').count()
# Out:
#        name  company  gender  birthday  height  blood  brand  nation
# group
# 과수원       1        1       1         1       1      1      1       1
# 뉴진스       5        5       5         5       5      4      5       5
# 레드벨벳      2        2       2         2       2      2      2       2
# 방탄소년단     5        5       5         5       5      5      5       5
# 블랙핑크      4        4       4         4       4      4      4       4
# 소녀시대      2        2       2         2       1      2      2       2
# 워너원       2        1       2         2       2      2      2       2

# %%
df_copy.groupby('group').mean(numeric_only=True) #numeric_only=True => 글자말고 숫자만 평균 내라 라는 의미 ########################
# Out:
#        height      brand
# group
# 과수원    160.00  1234567.0
# 뉴진스    166.04  3082933.2
# 레드벨벳   164.50  1786140.5
# 방탄소년단  178.40  3858656.0
# 블랙핑크   165.00  2024410.5
# 소녀시대   168.00  1982581.5
# 워너원    180.50  1830385.5

# %%
# 이름이 2글자인 사람의 그룹 같은식으로 데이터를 좀 더 세부적으로 조건을 거는 것도 가능 한가요?
df.groupby(df['name'].str.len())[['name']].count()

# %%
df_copy.groupby('group').sum(numeric_only=True) # 숫자만 뽑아서
# Out:
#        height     brand
# group
# 과수원     160.0   1234567
# 뉴진스     830.2  15414666
# 레드벨벳    329.0   3572281
# 방탄소년단   892.0  19293280
# 블랙핑크    660.0   8097642
# 소녀시대    168.0   3965163
# 워너원     361.0   3660771

# %%
df_copy.groupby('gender').mean(numeric_only=True)
# Out:
#             height         brand
# gender
# 남자      179.000000  3.279150e+06
# 여자      165.169231  2.306023e+06

# %%
# 1차 그룹, 2차그룹##############################################################


df_copy.groupby(['blood','gender']).mean(numeric_only=True) # 좀 더 세분화 할 수 있다
# Out:
#                height         brand
# blood gender
# A     남자      179.000  3.560683e+06
#       여자      164.500  2.209151e+06
# AB    남자      179.000  3.470048e+06
# B     여자      165.875  2.004014e+06
# O     남자      179.000  1.680587e+06
#       여자      165.850  3.231469e+06

# %%
df_copy.groupby(['gender','blood']).mean(numeric_only=True)
# Out:
#                height         brand
# gender blood
# 남자     A      179.000  3.560683e+06
#        AB     179.000  3.470048e+06
#        O      179.000  1.680587e+06
# 여자     A      164.500  2.209151e+06
#        B      165.875  2.004014e+06
#        O      165.850  3.231469e+06

# %%
df_copy.groupby(['blood','gender'])['height'].mean() # 어차피 height는 숫자이므로 numeric 명시 필요 없다
# Out:
# blood  gender
# A      남자        179.000
#        여자        164.500
# AB     남자        179.000
# B      여자        165.875
# O      남자        179.000
#        여자        165.850
# Name: height, dtype: float64

# %% [markdown]
# #**10. 중복값 제거하기**

# %%
df_copy['blood']
# Out:
# 0       A
# 1       A
# 2       A
# 3       O
# 4      AB
# 5     NaN
# 6       O
# 7       A
# 8       B
# 9       A
# 10      A
# 11      B
# 12      A
# 13      A
# 14      B
# 15      B
# 16      A
# 17      A
# 18      A
# 19      O
# 20      A
# Name: blood, dtype: object

# %%
# drop_duplicates(): 중복된 데이터를 제거#############################


df_copy['blood'].drop_duplicates() # 맨처음으로 오는 첫데이터 인덱스값
# Out:
# 0      A
# 3      O
# 4     AB
# 5    NaN
# 8      B
# Name: blood, dtype: object

# %%
df_copy['blood'].drop_duplicates(keep='last') #keep='last' =>첫데이터가 아닌 마지막값 인덱스 보여줌
# Out:
# 4      AB
# 5     NaN
# 15      B
# 19      O
# 20      A
# Name: blood, dtype: object

# %%
# value_counts(): 열의 각 값에 대한 데이터의 개수를 반환. 기본은 NaN을 생략#########################
# 중요#########################

df_copy['blood'].value_counts() # 이 시리즈에서 이 해당 컬럼에서 해당 데이터가 어떤 종류가 있는지, 그 데이터가 몇개씩 들어있는지 확인가능
# Out:
# blood
# A     12
# B      4
# O      3
# AB     1
# Name: count, dtype: int64

# %%
df_copy['company'].value_counts()
# Out:
# company
# 빅히트     7
# 어도어     5
# 와이지     4
# 에스엠     2
# 판타지오    1
# 애플      1
# Name: count, dtype: int64

# %%
df_copy['company'].value_counts(dropna=False) # NaN를 포함 #################################
# Out:
# company
# 빅히트     7
# 어도어     5
# 와이지     4
# 에스엠     2
# 판타지오    1
# NaN     1
# 애플      1
# Name: count, dtype: int64

# %% [markdown]
# #**11. 데이터프레임 합치기**

# %%
df1 = pd.read_csv('/content/drive/MyDrive/AI활용 멀티모달 MCP PJ 시즌1/2. 데이터 분석/data/idol.csv')
df2 = pd.read_csv('/content/drive/MyDrive/AI활용 멀티모달 MCP PJ 시즌1/2. 데이터 분석/data/idol2.csv')

# %%
df1
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327
# 13    리사   블랙핑크   와이지  여자  1997-03-27  167.0    A  1912800
# 14    로제   블랙핑크   와이지  여자  1997-02-11  168.0    B  1888132
# ...

# %%
df2
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 1     정국  3500    3
# 2     민지  3200    4
# 3     하니  3050    4
# 4      뷔  4300    3
# 5    다니엘  2900    5
# 6     혜인  3400    6
# 7     지수  4500    5
# 8     해린  4200    4
# 9     태연  4300    4
# 10    RM  3700    3
# 11    제니  3850    5
# 12   옹성우  3900    4
# 13    리사  4100    3
# 14    로제  4150    3
# 15    윤아  3000    3
# 16    조이  3500    3
# 17    슬기  3200    4
# 18  강다니엘  3050    4
# 19     진  4300    3

# %%
df_copy = df1.copy()

# %%
pd.concat([df1, df_copy]) # axis=0 (기본값)(행으로 연결) # 데이터 합치기
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327
# 13    리사   블랙핑크   와이지  여자  1997-03-27  167.0    A  1912800
# 14    로제   블랙핑크   와이지  여자  1997-02-11  168.0    B  1888132
# ...

# %%
df_concat = pd.concat([df1, df_copy]) # 인덱스가 망가져있다

# %%
# reset_index(): index를 새롭게 적용 #######################################
# drop=True 옵션을 사용하여 기존 index가 컬럼으로 만들어지는 것을 방지######################################
df_concat.reset_index(drop=True) #drop=True 그럼 기존의 인덱스는 컬럼으로 만들어지는데 이거를 기존 인덱스를 없어지게 함 #################################
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327
# 13    리사   블랙핑크   와이지  여자  1997-03-27  167.0    A  1912800
# 14    로제   블랙핑크   와이지  여자  1997-02-11  168.0    B  1888132
# ...

# %%
pd.concat([df1, df2], axis=1) # 같은 index와 결합 # 열로 합침 # 같은인덱스끼리 결합하였다 ##################################
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수    이름    연봉  가족수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302    지민  3000    3
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844    정국  3500    3
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081    민지  3200    4
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153    하니  3050    4
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048     뷔  4300    3
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271   다니엘  2900    5
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785    혜인  3400    6
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460    지수  4500    5
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376    해린  4200    4
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866    태연  4300    4
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499    RM  3700    3
# ...

# %%
df3 = df2.drop([1, 3, 5, 7, 9])  #df2에서 1,3,5,7,9 삭제하였따
df3
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 2     민지  3200    4
# 4      뷔  4300    3
# 6     혜인  3400    6
# 8     해린  4200    4
# 10    RM  3700    3
# 11    제니  3850    5
# 12   옹성우  3900    4
# 13    리사  4100    3
# 14    로제  4150    3
# 15    윤아  3000    3
# 16    조이  3500    3
# 17    슬기  3200    4
# 18  강다니엘  3050    4
# 19     진  4300    3

# %%
pd.concat([df1, df3], axis=1) # 인덱스 번호로 합치기때문에 없는 것은 NaN으로 #####################################
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수    이름      연봉  가족수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302    지민  3000.0  3.0
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844   NaN     NaN  NaN
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081    민지  3200.0  4.0
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153   NaN     NaN  NaN
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048     뷔  4300.0  3.0
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271   NaN     NaN  NaN
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785    혜인  3400.0  6.0
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460   NaN     NaN  NaN
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376    해린  4200.0  4.0
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866   NaN     NaN  NaN
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499    RM  3700.0  3.0
# ...

# %%
df_right = df2.drop([1, 3, 5, 7, 9], axis=0)  #axis=0 행을 날림
df_right
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 2     민지  3200    4
# 4      뷔  4300    3
# 6     혜인  3400    6
# 8     해린  4200    4
# 10    RM  3700    3
# 11    제니  3850    5
# 12   옹성우  3900    4
# 13    리사  4100    3
# 14    로제  4150    3
# 15    윤아  3000    3
# 16    조이  3500    3
# 17    슬기  3200    4
# 18  강다니엘  3050    4
# 19     진  4300    3

# %%
df_right = df_right.reset_index(drop=True) # 인덱스 리셋
df_right
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 1     민지  3200    4
# 2      뷔  4300    3
# 3     혜인  3400    6
# 4     해린  4200    4
# 5     RM  3700    3
# 6     제니  3850    5
# 7    옹성우  3900    4
# 8     리사  4100    3
# 9     로제  4150    3
# 10    윤아  3000    3
# 11    조이  3500    3
# 12    슬기  3200    4
# 13  강다니엘  3050    4
# 14     진  4300    3

# %%
dic = {
    '이름': '김사과',
    '연봉': 9000,
    '가족수': 10
}

# %%
# 추가
df_right = pd.concat([df_right, pd.DataFrame(dic, index=[0])], ignore_index=True)
df_right
#df1에는 김사과 없음
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 1     민지  3200    4
# 2      뷔  4300    3
# 3     혜인  3400    6
# 4     해린  4200    4
# 5     RM  3700    3
# 6     제니  3850    5
# 7    옹성우  3900    4
# 8     리사  4100    3
# 9     로제  4150    3
# 10    윤아  3000    3
# 11    조이  3500    3
# 12    슬기  3200    4
# 13  강다니엘  3050    4
# 14     진  4300    3
# 15   김사과  9000   10

# %%
pd.concat([df1, df_right], axis=1) # 인덱스로 합치니 엉망으로 된다
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수    이름      연봉   가족수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302    지민  3000.0   3.0
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844    민지  3200.0   4.0
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081     뷔  4300.0   3.0
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153    혜인  3400.0   6.0
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048    해린  4200.0   4.0
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271    RM  3700.0   3.0
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785    제니  3850.0   5.0
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460   옹성우  3900.0   4.0
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376    리사  4100.0   3.0
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866    로제  4150.0   3.0
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499    윤아  3000.0   3.0
# ...

# %%
# 이때 나오는 것
# merge(): 특정 고유한 키(unique, id)값을 기준으로 합침
# merge(데이터프레임1, 데이터프레임2, on='유니크값', how='병합의 기준') ####################################
# 병합의 기준: left, right, inner, cross
pd.merge(df1, df_right, on='이름', how='left')
#on='이름' 이름과 동일한 것끼리 합친다/how='left' => df1(완쪽)데이터는 다 가져오고 왼쪽을 기준으로 오른쪽데이터를 그에 맞춰서 넣겠다라는 의미
############################################################김사과 없음
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수      연봉  가족수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302  3000.0  3.0
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844     NaN  NaN
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081  3200.0  4.0
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153     NaN  NaN
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048  4300.0  3.0
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271     NaN  NaN
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785  3400.0  6.0
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460     NaN  NaN
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376  4200.0  4.0
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866     NaN  NaN
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499  3700.0  3.0
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250  3850.0  5.0
# ...

# %%
pd.merge(df1, df_right, on='이름', how='right') # df_right(오른쪽)데이터 중심으로 오른쪽데이터 다 가져오고 df1이 그에 이름 맞춰 넣어줌
# 김사과 존재 ############################################
# Out:
#       이름     그룹   소속사   성별        생년월일      키  혈액형    브랜드평판지수    연봉  가족수
# 0     지민  방탄소년단   빅히트   남자  1995-10-13  174.0    A  6267302.0  3000    3
# 1     민지    뉴진스   어도어   여자  2004-05-07  169.0    A  4437081.0  3200    4
# 2      뷔  방탄소년단   빅히트   남자  1995-12-30  179.0   AB  3470048.0  4300    3
# 3     혜인    뉴진스   어도어   여자  2008-04-21  170.0    O  2301785.0  3400    6
# 4     해린    뉴진스   어도어   여자  2006-05-15  164.5    B  2173376.0  4200    4
# 5     RM  방탄소년단   빅히트   남자  1994-09-12  181.0    A  2069499.0  3700    3
# 6     제니   블랙핑크   와이지   여자  1996-01-16  163.0    B  2069250.0  3850    5
# 7    옹성우    워너원  판타지오   남자  1995-08-25  179.0    A  1954327.0  3900    4
# 8     리사   블랙핑크   와이지   여자  1997-03-27  167.0    A  1912800.0  4100    3
# 9     로제   블랙핑크   와이지   여자  1997-02-11  168.0    B  1888132.0  4150    3
# 10    윤아   소녀시대   에스엠   여자  1990-05-30  168.0    B  1885297.0  3000    3
# 11    조이   레드벨벳   빅히트   여자  1996-09-03  168.0    A  1830514.0  3500    3
# ...

# %%
pd.merge(df1, df_right, on='이름', how='inner') # 둘다 있는 것만 합침/교집합으로
# Out:
#       이름     그룹   소속사  성별        생년월일      키 혈액형  브랜드평판지수    연봉  가족수
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0   A  6267302  3000    3
# 1     민지    뉴진스   어도어  여자  2004-05-07  169.0   A  4437081  3200    4
# 2      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0  AB  3470048  4300    3
# 3     혜인    뉴진스   어도어  여자  2008-04-21  170.0   O  2301785  3400    6
# 4     해린    뉴진스   어도어  여자  2006-05-15  164.5   B  2173376  4200    4
# 5     RM  방탄소년단   빅히트  남자  1994-09-12  181.0   A  2069499  3700    3
# 6     제니   블랙핑크   와이지  여자  1996-01-16  163.0   B  2069250  3850    5
# 7    옹성우    워너원  판타지오  남자  1995-08-25  179.0   A  1954327  3900    4
# 8     리사   블랙핑크   와이지  여자  1997-03-27  167.0   A  1912800  4100    3
# 9     로제   블랙핑크   와이지  여자  1997-02-11  168.0   B  1888132  4150    3
# 10    윤아   소녀시대   에스엠  여자  1990-05-30  168.0   B  1885297  3000    3
# 11    조이   레드벨벳   빅히트  여자  1996-09-03  168.0   A  1830514  3500    3
# 12    슬기   레드벨벳   빅히트  여자  1994-02-10  161.0   A  1741767  3200    4
# ...

# %%
pd.merge(df1, df_right, how='cross') # 합집합 둘다 모든 데이터 가져오기
# Out:
#     이름_x     그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수  이름_y    연봉  가족수
# 0     지민  방탄소년단  빅히트  남자  1995-10-13  174.0   A  6267302    지민  3000    3
# 1     지민  방탄소년단  빅히트  남자  1995-10-13  174.0   A  6267302    민지  3200    4
# 2     지민  방탄소년단  빅히트  남자  1995-10-13  174.0   A  6267302     뷔  4300    3
# 3     지민  방탄소년단  빅히트  남자  1995-10-13  174.0   A  6267302    혜인  3400    6
# 4     지민  방탄소년단  빅히트  남자  1995-10-13  174.0   A  6267302    해린  4200    4
# ..   ...    ...  ...  ..         ...    ...  ..      ...   ...   ...  ...
# 315    진  방탄소년단  빅히트  남자  1992-12-04  179.0   O  1680587    조이  3500    3
# 316    진  방탄소년단  빅히트  남자  1992-12-04  179.0   O  1680587    슬기  3200    4
# 317    진  방탄소년단  빅히트  남자  1992-12-04  179.0   O  1680587  강다니엘  3050    4
# 318    진  방탄소년단  빅히트  남자  1992-12-04  179.0   O  1680587     진  4300    3
# 319    진  방탄소년단  빅히트  남자  1992-12-04  179.0   O  1680587   김사과  9000   10
#
# [320 rows x 11 columns]

# %% [markdown]
# #**12. 등수 매기기**

# %%
df1['브랜드평판지수'].rank()
# Out:
# 0     20.0
# 1     19.0
# 2     18.0
# 3     17.0
# 4     16.0
# 5     15.0
# 6     14.0
# 7     13.0
# 8     12.0
# 9     11.0
# 10    10.0
# 11     9.0
# 12     8.0
# 13     7.0
# 14     6.0
# 15     5.0
# 16     4.0
# 17     3.0
# 18     2.0
# 19     1.0
# Name: 브랜드평판지수, dtype: float64

# %%
# rank(): 데이터프레임 또는 시리즈의 순위를 매기는 함수. 기본값은 ascending
df1['브랜드순위'] = df1['브랜드평판지수'].rank()
df1
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수  브랜드순위
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302   20.0
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844   19.0
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081   18.0
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153   17.0
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048   16.0
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271   15.0
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785   14.0
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460   13.0
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376   12.0
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866   11.0
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499   10.0
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250    9.0
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327    8.0
# ...

# %%
df1['브랜드순위'] = df1['브랜드평판지수'].rank(ascending=False) #오름차순으로
df1
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수  브랜드순위
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302    1.0
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844    2.0
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081    3.0
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153    4.0
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048    5.0
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271    6.0
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785    7.0
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460    8.0
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376    9.0
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866   10.0
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499   11.0
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250   12.0
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327   13.0
# ...

# %%
# astype(): 특정열의 자료형을 변경##############################
df1['브랜드순위'] = df1['브랜드순위'].astype(int)
df1
# Out:
#       이름     그룹   소속사  성별        생년월일      키  혈액형  브랜드평판지수  브랜드순위
# 0     지민  방탄소년단   빅히트  남자  1995-10-13  174.0    A  6267302      1
# 1     정국  방탄소년단   빅히트  남자  1997-09-01  179.0    A  5805844      2
# 2     민지    뉴진스   어도어  여자  2004-05-07  169.0    A  4437081      3
# 3     하니    뉴진스   어도어  여자  2004-10-06  161.7    O  4161153      4
# 4      뷔  방탄소년단   빅히트  남자  1995-12-30  179.0   AB  3470048      5
# 5    다니엘    뉴진스   어도어  여자  2005-04-11  165.0  NaN  2341271      6
# 6     혜인    뉴진스   어도어  여자  2008-04-21  170.0    O  2301785      7
# 7     지수   블랙핑크   와이지  여자  1995-01-03  162.0    A  2227460      8
# 8     해린    뉴진스   어도어  여자  2006-05-15  164.5    B  2173376      9
# 9     태연   소녀시대   에스엠  여자  1989-03-09    NaN    A  2079866     10
# 10    RM  방탄소년단   빅히트  남자  1994-09-12  181.0    A  2069499     11
# 11    제니   블랙핑크   와이지  여자  1996-01-16  163.0    B  2069250     12
# 12   옹성우    워너원  판타지오  남자  1995-08-25  179.0    A  1954327     13
# ...

# %%
df1['브랜드순위'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# #**13. 날짜타입 사용하기**

# %%
df_copy = df.copy()
df_copy
# Out:
#     name  group company gender    birthday  height blood    brand
# 0     지민  방탄소년단     빅히트     남자  1995-10-13   174.0     A  6267302
# 1     정국  방탄소년단     빅히트     남자  1997-09-01   179.0     A  5805844
# 2     민지    뉴진스     어도어     여자  2004-05-07   169.0     A  4437081
# 3     하니    뉴진스     어도어     여자  2004-10-06   161.7     O  4161153
# 4      뷔  방탄소년단     빅히트     남자  1995-12-30   179.0    AB  3470048
# 5    다니엘    뉴진스     어도어     여자  2005-04-11   165.0   NaN  2341271
# 6     혜인    뉴진스     어도어     여자  2008-04-21   170.0     O  2301785
# 7     지수   블랙핑크     와이지     여자  1995-01-03   162.0     A  2227460
# 8     해린    뉴진스     어도어     여자  2006-05-15   164.5     B  2173376
# 9     태연   소녀시대     에스엠     여자  1989-03-09     NaN     A  2079866
# 10    RM  방탄소년단     빅히트     남자  1994-09-12   181.0     A  2069499
# 11    제니   블랙핑크     와이지     여자  1996-01-16   163.0     B  2069250
# 12   옹성우    워너원    판타지오     남자  1995-08-25   179.0     A  1954327
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     object
#  1   group     20 non-null     object
#  2   company   19 non-null     object
#  3   gender    20 non-null     object
#  4   birthday  20 non-null     object
#  5   height    19 non-null     float64
#  6   blood     19 non-null     object
#  7   brand     20 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ KB

# %%
df_copy.info()['birthday'] #birthday 은 object 여서 날짜계산을 할 수 없다
# 그래서 타입 바꾸기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     object
#  1   group     20 non-null     object
#  2   company   19 non-null     object
#  3   gender    20 non-null     object
#  4   birthday  20 non-null     object
#  5   height    19 non-null     float64
#  6   blood     19 non-null     object
#  7   brand     20 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.4+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4042768006.py in <cell line: 0>()
# ----> 1 df_copy.info()['birthday'] #birthday 은 object 여서 날짜계산을 할 수 없다
#       2 # 그래서 타입 바꾸기
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# to_datatime(): object타입에서 datetime타입으로 변환
df_copy['birthday'] = pd.to_datetime(df_copy['birthday'])
print(type(df_copy['birthday'])) ####################################################시리즈
print(df_copy['birthday'].dtypes) ########################################################int변경

# %%
df_copy.info() #변경됨

# %%
df_copy['birthday'].dt.year #연도만 뽑을 수 있다

# %%
df_copy['birthday'].dt.month

# %%
df_copy['birthday'].dt.day

# %%
df_copy['birthday'].dt.hour #이 데이터는 시간 없으므로 0으로 표시

# %%
df_copy['birthday'].dt.minute

# %%
df_copy['birthday'].dt.second

# %%
df_copy['birthday'].dt.dayofweek # 요일: 0(월요일) ~ 6(일요일)

# %%
df_copy['birthday'].dt.isocalendar().week
#1월 1일부터 얼마만큼 '주'가 흘렀는지 알 수 있다/이번 년도에 몇번째 주인지 확인 가능

# %% [markdown]
# #**14. apply 사용하기**
# Pandas의 apply() 함수는 데이터프레임이나 시리즈의 데이터를 사용자 정의 함수 또는 내장 함수에 적용하여 새로운 값을 계산하거나 변환할 때 사용됩니다. 데이터를 행(row) 또는 열(column) 단위로 처리할 수 있는 강력한 도구입니다.

# %%
#apply함수 콜백함수에서 사용했었음/같은 녀석이 아니라 판다스 안에서도 apply가 있다

# %%
df_copy = df.copy()
df_copy

# %%
df_copy.head()

# %%
# 나중에 예측,비교 등 여러가지 여러가지 Ai모델에 학습을 시켜서 사용하려면 무조건 문자없이 숫자로 바꿔서 해야함
################################
# 성별을 남자는 1, 여자는 0으로 변환(loc를 사용)



df_copy.loc[df_copy['gender'] == '남자', 'gender'] = 1
df_copy.loc[df_copy['gender'] == '여자', 'gender'] = 0
#df_copy.loc[df_copy[행 조건, 'gender'만 보고싶어] 남자는 1 ?????????????????????????????????????????/

# %%
df_copy.head() #바뀌어있음

# %%
df_copy = df.copy() #다시 원본데이터 깨끗하게
df_copy

# %%
# 2번째 방법
def male_or_female(x):
    if x == '남자':
        return 1
    elif x == '여자':
        return 0
    else:
        return None

# %%
# 함수 테스트
print(male_or_female('남자'))
print(male_or_female('여자'))

# %%
#################################################apply적용해서 함수를 콜백으로 등록시켜 놓으면
df_copy['gender'].apply(male_or_female)
#데이터를 꺼내서 하나씩 함수에다가 다 집어넣는다/변환됨###############################
# apply(함수의 주소가 들어감) => 그럼 이 함수는 계속 메모리에 있게 된다
# 굳이 메모리에 넣을까? 한번쓰고 버릴건데?

# %%
# 그래서 lamda함수 나옴
df_copy['gender'].apply(lambda x: 1 if x == '남자' else 0)

# %%
df_copy['NewGender'] = df_copy['gender'].apply(lambda x: 1 if x == '남자' else 0) #['NewGender']여기다가 저장
df_copy.head()

# %%
# 그러면 이름 같은건 숫자로 어떻게 바꿔?
# 근데 학습할때 이름은 필요없다 개인정보 필요없음
# 지역-서울,듣등 숫자로 다 바꿔줄 수 있다

# %% [markdown]
# #**15. map 사용하기**
# Pandas의 map() 함수는 Series 객체에서 사용할 수 있는 함수로, 각 요소에 대해 함수나 매핑 규칙을 적용하여 새로운 값을 계산하거나 변환할 때 사용됩니다. map()은 데이터의 각 요소를 순회하며 특정 작업을 수행하므로, 데이터를 가공하거나 변환하는 데 유용합니다.

# %%
df_copy = df.copy()
df_copy

# %%
map_gender = {'남자':1, '여자':0} #dic으로

# %%
df_copy['gender'].map(map_gender)
 #dictionary를 map으로 적용 그에 해당하는 key와 값으로 변형/key로 구분해서###################

# %%
df_copy['NewGender'] = df_copy['gender'].map(map_gender)
df_copy.head()

# %%
# lambda => 함수를 한번쓰고 버린다
# map => 실제 모든 데이터에 특정계산을 적용하고 싶을때

# %%
####################################
# apply => 특정함수 적용
# map => 다 어떤 특정 계산을 적용할 때
# 실제 두개다 비슷한 연산 할 수 있음

# %% [markdown]
# #**16. 데이터프레임의 산술연산**

# %%
df1 = pd.DataFrame({
    '파이썬':[60, 70, 80, 90, 95],
    '데이터분석':[40, 60, 70, 55, 87],
    '머신러닝딥러닝':[35, 40, 30, 70, 55]
})

# %%
df1

# %%
df1['파이썬'].dtypes #####################################

# %%
type(df1['파이썬']) ##################################

# %%
df1['파이썬'] + df1['데이터분석'] + df1['머신러닝딥러닝']
# 각각 다 더해짐/총점

# %%
# df1에 총점, 평균이라는 파생변수를 만들고 파생변수에 총점, 평균을 구해서 저장
df1['총점'] = df1['파이썬'] + df1['데이터분석'] + df1['머신러닝딥러닝'] #총점이라는 컬럼 만듦

df1
# 파이썬	데이터분석	머신러닝딥러닝	 => 컬럼이기도 하지만 이거를 변수라고도 부르기도 함
# 이 변수에서 하나의 새로운 변수를 만듦 = 파생변수 => 총점 #################################

# %%
df1['평균'] = df1['총점'] / 3
df1
# 각각의 변수를 더하면 새로운 변수를 만들 수 있따

# %%
df1['파이썬'].sum() # df1['파이썬'].sum(axis=0) #행끼리의 ;덧셈

# %%
df1['파이썬'].mean()

# %%
df1.sum() # 모든 컬럼의 sum

# %%
df1.mean()

# %%
df1 = pd.DataFrame({
    '파이썬':[60, 70, 80, 90, 95],
    '데이터분석':[40, 60, 70, 55, 87],
    '머신러닝딥러닝':[35, 40, 30, 70, 55]
})

df2 = pd.DataFrame({
    '파이썬':['C', 'B', 'B', 'A', 'A'],
    '데이터분석':[40, 60, 70, 55, 87],
    '머신러닝딥러닝':[35, 40, 30, 70, 55]
})

# %%
df1

# %%
df2

# %%
# df1 + df2 # TypeError: unsupported operand type(s) for +: 'int' and 'str'
df1 + 10  # 다 int이므로 가능
# df2 + 10 # TypeError: can only concatenate str (not "int") to str

# %%
df1 = pd.DataFrame({
    '데이터분석':[40, 60, 70, 55, 87],
    '머신러닝딥러닝':[35, 40, 30, 70, 55]
})

df2 = pd.DataFrame({
    '데이터분석':[40, 60, 70, 55],
    '머신러닝딥러닝':[35, 40, 30, 70]
})

# %%
df1 + df2
# 행의 갯수가 다를 경우 빠진 데이터를 NaN으로 취급하기 때문에 결과는 NaN###########################

# %% [markdown]
# #**17. select_dtypes**

# %%
df_copy = df.copy()
df_copy

# %%
df.info()

# %%
 # 문자열 컬럼만 가져오기#### 특정 dtype만으로 데이터를 확인###################################


df.select_dtypes(include='object') # 문자열 컬럼만 가져오기

# %%
 # 문자열 컬럼만 빼고 가져오기


df.select_dtypes(exclude='object') # 문자열 컬럼만 빼고 가져오기

# %%
# 문자가 아닌 컬럼에만 10을 더함


df.select_dtypes(exclude='object') + 10

# %%
# 문자열을 가지고 있는 컬럼의 이름만 변수에 저장하여 출력

str_cols = df.select_dtypes(include='object').columns
str_cols

# %%
df[str_cols]

# %%
# 실제 데이터를 숫자화 시키는 것 = get_dummies
