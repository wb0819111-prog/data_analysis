# %% [markdown]
# #**1. 공공데이터**
# 공공데이터(data.go.kr)는 대한민국 정부에서 운영하는 공공데이터 포털로, 공공기관이 보유한 다양한 데이터를 국민과 기업, 개발자 등에게 개방하여 활용할 수 있도록 제공하는 플랫폼입니다. 데이터를 파일 형식(Excel, CSV 등)으로 다운로드하거나, API 형태로 실시간 연동하여 사용할 수 있습니다.
#
# 1. ["소상공인시장진흥공단_상가(상권)정보"](https://www.data.go.kr/data/15083033/fileData.do)을 검색 후  압축파일을 다운로드합니다.
#
# 2. 압축을 해제하고 "서울" csv 데이터를 구글드라이브에 업로드합니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# low_memory=True : 파일을 조각 단위로 조금씩 읽어서 메모리를 아끼는 방법. 데이터 타입을 정확하게 못 맞추는 경우가 있음
# low_memory=False : 파일 전체를 한번에 읽어서 dtpye을 정확하게 판단함. 메모리를 더 많이 사용함
shop = pd.read_csv('/content/drive/MyDrive/AI활용 멀티모달 MCP PJ 시즌1/2. 데이터 분석/data/소상공인시장진흥공단_상가(상권)정보_서울_202510.csv', low_memory=False)
shop
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220802495368  영어독서클럽영어교습소  NaN        P1       교육      P105
# 1       MA010120220806509545         하루달곰  NaN        I2       음식      I210
# 2       MA010120220804193917          양산박  NaN        I2       음식      I201
# 3       MA010120220805914597   으뜸공인중개사사무소  NaN        L1      부동산      L102
# 4       MA010120220814395227        세선티알엠  NaN        N1  시설관리·임대      N103
# ...                      ...          ...  ...       ...      ...       ...
# 536257  MA0101202306A0044326          신인류  NaN        I2       음식      I211
# 536258  MA0101202306A0026957            휴  NaN        I2       음식      I201
# 536259  MA0101202306A0041780     참기름짜는육회집  NaN        I2       음식      I201
# 536260  MA0101202306A0033595   신사공인중개사사무소  NaN        L1      부동산      L102
# 536261  MA0101202306A0015005         거마농장  NaN        I2       음식      I201
#
# ...

# %%
pd.set_option('display.max_columns', 40) # 컬럼을 다 확인가능하다 왜 40으로 하면 다 볼 수 있나????????????
shop
# Out:
#                       상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0       MA010120220802495368  영어독서클럽영어교습소  NaN        P1       교육      P105
# 1       MA010120220806509545         하루달곰  NaN        I2       음식      I210
# 2       MA010120220804193917          양산박  NaN        I2       음식      I201
# 3       MA010120220805914597   으뜸공인중개사사무소  NaN        L1      부동산      L102
# 4       MA010120220814395227        세선티알엠  NaN        N1  시설관리·임대      N103
# ...                      ...          ...  ...       ...      ...       ...
# 536257  MA0101202306A0044326          신인류  NaN        I2       음식      I211
# 536258  MA0101202306A0026957            휴  NaN        I2       음식      I201
# 536259  MA0101202306A0041780     참기름짜는육회집  NaN        I2       음식      I201
# 536260  MA0101202306A0033595   신사공인중개사사무소  NaN        L1      부동산      L102
# 536261  MA0101202306A0015005         거마농장  NaN        I2       음식      I201
#
# ...

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536262 entries, 0 to 536261
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     536262 non-null  object
#  1   상호명        536262 non-null  object
#  2   지점명        47467 non-null   object
#  3   상권업종대분류코드  536262 non-null  object
#  4   상권업종대분류명   536262 non-null  object
#  5   상권업종중분류코드  536262 non-null  object
#  6   상권업종중분류명   536262 non-null  object
#  7   상권업종소분류코드  536262 non-null  object
#  8   상권업종소분류명   536262 non-null  object
#  9   표준산업분류코드   536061 non-null  object
#  10  표준산업분류명    536061 non-null  object
#  11  시도코드       536262 non-null  int64
#  12  시도명        536262 non-null  object
#  13  시군구코드      536262 non-null  int64
#  14  시군구명       536262 non-null  object
#  15  행정동코드      536262 non-null  int64
#  16  행정동명       536262 non-null  object
#  17  법정동코드      536262 non-null  int64
#  18  법정동명       536262 non-null  object
# ...

# %%
shop.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
# 필요하다고 생각하는 컬럼들만 가져오기
view_columns = ['상호명', '지점명', '상권업종대분류명', '상권업종중분류명',
                '상권업종소분류명', '시도명', '시군구명', '도로명', '도로명주소',
                '경도', '위도']

shop = shop[view_columns]
shop.head()
# Out:
#            상호명  지점명 상권업종대분류명 상권업종중분류명       상권업종소분류명    시도명 시군구명  \
# 0  영어독서클럽영어교습소  NaN       교육    일반 교육        입시·교과학원  서울특별시  강서구
# 1         하루달곰  NaN       음식    기타 간이           빵/도넛  서울특별시  노원구
# 2          양산박  NaN       음식       한식         백반/한정식  서울특별시  서초구
# 3   으뜸공인중개사사무소  NaN      부동산  부동산 서비스     부동산 중개/대리업  서울특별시  마포구
# 4        세선티알엠  NaN  시설관리·임대    조경·유지  조경 유지·관리 서비스업  서울특별시  관악구
#
#                  도로명                  도로명주소          경도         위도
# 0  서울특별시 강서구 공항대로41길   서울특별시 강서구 공항대로41길 51  126.845780  37.560238
# 1    서울특별시 노원구 상계로1길  서울특별시 노원구 상계로1길 82-14  127.062003  37.659314
# 2    서울특별시 서초구 언남11길   서울특별시 서초구 언남11길 34-1  127.043051  37.475637
# 3      서울특별시 마포구 숭문길      서울특별시 마포구 숭문길 182  126.946651  37.554524
# 4      서울특별시 관악구 호암로      서울특별시 관악구 호암로 538  126.931669  37.465579

# %%
shop.isnull().sum()
# Out:
# 상호명              0
# 지점명         488795
# 상권업종대분류명         0
# 상권업종중분류명         0
# 상권업종소분류명         0
# 시도명              0
# 시군구명             0
# 도로명              0
# 도로명주소            0
# 경도               0
# 위도               0
# dtype: int64

# %%
# 한글 다운로드 이거 먼저 실행하고, 런타임 세션다시시작 및 모두실행
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (10.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
# 산점도 그리기
plt.figure(figsize=(6, 8))  # 그래프 크기 설정
plt.scatter(shop['경도'], shop['위도'])  # 산점도 그리기 scatter 점으로
plt.xlabel('경도')  # x축 레이블
plt.ylabel('위도')  # y축 레이블
plt.grid(True)  # 그리드 추가 grid->눈금자 표시
plt.show()  # 그래프 출력
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
# ...

# %%
len(shop)
# Out:
# 536262

# %%
shop.loc[shop['도로명주소'].str.startswith('서울')] #startswith =>str과 관련된 메소드
# Out:
#                 상호명  지점명 상권업종대분류명 상권업종중분류명       상권업종소분류명    시도명 시군구명  \
# 0       영어독서클럽영어교습소  NaN       교육    일반 교육        입시·교과학원  서울특별시  강서구
# 1              하루달곰  NaN       음식    기타 간이           빵/도넛  서울특별시  노원구
# 2               양산박  NaN       음식       한식         백반/한정식  서울특별시  서초구
# 3        으뜸공인중개사사무소  NaN      부동산  부동산 서비스     부동산 중개/대리업  서울특별시  마포구
# 4             세선티알엠  NaN  시설관리·임대    조경·유지  조경 유지·관리 서비스업  서울특별시  관악구
# ...             ...  ...      ...      ...            ...    ...  ...
# 536257          신인류  NaN       음식       주점          요리 주점  서울특별시  종로구
# 536258            휴  NaN       음식       한식         백반/한정식  서울특별시  강남구
# 536259     참기름짜는육회집  NaN       음식       한식       소고기 구이/찜  서울특별시  송파구
# 536260   신사공인중개사사무소  NaN      부동산  부동산 서비스     부동산 중개/대리업  서울특별시  강남구
# 536261         거마농장  NaN       음식       한식      돼지고기 구이/찜  서울특별시  송파구
#
#                        도로명                  도로명주소          경도         위도
# ...

# %%
shop.loc[~shop['도로명주소'].str.startswith('서울')]
# Out:
# Empty DataFrame
# Columns: [상호명, 지점명, 상권업종대분류명, 상권업종중분류명, 상권업종소분류명, 시도명, 시군구명, 도로명, 도로명주소, 경도, 위도]
# Index: []

# %% [markdown]
# #**2. Seaborn**
# [Seaborn](https://seaborn.pydata.org/)은 Python의 데이터 시각화 라이브러리로, Matplotlib 위에 구축되어 데이터를 더 간단하고 쉽게 시각화할 수 있도록 설계되었습니다. 주로 통계적 데이터 시각화에 초점이 맞춰져 있으며, 다양한 차트와 스타일 옵션을 제공합니다.

# %%
# pip install seaborn 코랩에는 이미설치

# %%
import seaborn as sns

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop, x='경도', y='위도', hue='시군구명')
#hue => 시군구명을 일단 범례로 두겠다라는 것 종류별로/시군구명을 토대로 색깔을 자동으로 구별
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
shop.head()
# Out:
#            상호명  지점명 상권업종대분류명 상권업종중분류명       상권업종소분류명    시도명 시군구명  \
# 0  영어독서클럽영어교습소  NaN       교육    일반 교육        입시·교과학원  서울특별시  강서구
# 1         하루달곰  NaN       음식    기타 간이           빵/도넛  서울특별시  노원구
# 2          양산박  NaN       음식       한식         백반/한정식  서울특별시  서초구
# 3   으뜸공인중개사사무소  NaN      부동산  부동산 서비스     부동산 중개/대리업  서울특별시  마포구
# 4        세선티알엠  NaN  시설관리·임대    조경·유지  조경 유지·관리 서비스업  서울특별시  관악구
#
#                  도로명                  도로명주소          경도         위도
# 0  서울특별시 강서구 공항대로41길   서울특별시 강서구 공항대로41길 51  126.845780  37.560238
# 1    서울특별시 노원구 상계로1길  서울특별시 노원구 상계로1길 82-14  127.062003  37.659314
# 2    서울특별시 서초구 언남11길   서울특별시 서초구 언남11길 34-1  127.043051  37.475637
# 3      서울특별시 마포구 숭문길      서울특별시 마포구 숭문길 182  126.946651  37.554524
# 4      서울특별시 관악구 호암로      서울특별시 관악구 호암로 538  126.931669  37.465579

# %%
shop['상권업종대분류명'].value_counts() # 중복되지 않은 분류를 볼수 있다
# Out:
# 상권업종대분류명
# 음식         135274
# 소매         111415
# 과학·기술       94008
# 수리·개인       51673
# 교육          45524
# 부동산         25619
# 시설관리·임대     24588
# 예술·스포츠      20420
# 보건의료        18750
# 숙박           8991
# Name: count, dtype: int64

# %%
shop_edu = shop[shop['상권업종대분류명'] == '교육']
shop_edu
# Out:
#                   상호명  지점명 상권업종대분류명 상권업종중분류명       상권업종소분류명    시도명  시군구명  \
# 0         영어독서클럽영어교습소  NaN       교육    일반 교육        입시·교과학원  서울특별시   강서구
# 7       해피파파부설국가정책연구원  NaN       교육    기타 교육        직원 훈련기관  서울특별시  영등포구
# 29              리틀파티쉐  NaN       교육    기타 교육  기타 기술/직업 훈련학원  서울특별시   송파구
# 31              테크빌교육  NaN       교육    교육 지원   기타 교육지원 서비스업  서울특별시   강남구
# 42        한국스포츠의과학진흥원  NaN       교육    교육 지원         교육컨설팅업  서울특별시   강남구
# ...               ...  ...      ...      ...            ...    ...   ...
# 536226       씨앤씨18관학원  NaN       교육    일반 교육        입시·교과학원  서울특별시   강서구
# 536227    그리고만들고미술교습소  NaN       교육    기타 교육           미술학원  서울특별시  영등포구
# 536228        선화미술교습소  NaN       교육    기타 교육           미술학원  서울특별시   중랑구
# 536234    행복한미술관미술교습소  NaN       교육    기타 교육           미술학원  서울특별시  서대문구
# 536236    에꼴드에땅장안미술학원  NaN       교육    기타 교육           미술학원  서울특별시  동대문구
#
#                         도로명                   도로명주소          경도         위도
# ...

# %%
shop_edu.shape #45524개, 11개의 컬럼
# Out:
# (45524, 11)

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop_edu, x='경도', y='위도', hue='상권업종중분류명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
shop_edu_etc = shop_edu[shop_edu['상권업종중분류명'] == '기타 교육']
shop_edu_etc
# Out:
#                   상호명  지점명 상권업종대분류명 상권업종중분류명       상권업종소분류명    시도명  시군구명  \
# 7       해피파파부설국가정책연구원  NaN       교육    기타 교육        직원 훈련기관  서울특별시  영등포구
# 29              리틀파티쉐  NaN       교육    기타 교육  기타 기술/직업 훈련학원  서울특별시   송파구
# 47               블루밍엠  NaN       교육    기타 교육  기타 기술/직업 훈련학원  서울특별시   송파구
# 65              판도라박스  NaN       교육    기타 교육  기타 기술/직업 훈련학원  서울특별시   마포구
# 136              헤리티진  NaN       교육    기타 교육  기타 기술/직업 훈련학원  서울특별시   송파구
# ...               ...  ...      ...      ...            ...    ...   ...
# 536182       마이무브필라테스  NaN       교육    기타 교육     요가/필라테스 학원  서울특별시   마포구
# 536227    그리고만들고미술교습소  NaN       교육    기타 교육           미술학원  서울특별시  영등포구
# 536228        선화미술교습소  NaN       교육    기타 교육           미술학원  서울특별시   중랑구
# 536234    행복한미술관미술교습소  NaN       교육    기타 교육           미술학원  서울특별시  서대문구
# 536236    에꼴드에땅장안미술학원  NaN       교육    기타 교육           미술학원  서울특별시  동대문구
#
#                         도로명                   도로명주소          경도         위도
# ...

# %%
shop_edu_etc.shape
# Out:
# (24206, 11)

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop_edu_etc, x='경도', y='위도', hue='상권업종소분류명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
shop_edu_etc_computer = shop_edu_etc[shop_edu_etc['상권업종소분류명'] == '컴퓨터 학원']
shop_edu_etc_computer
# Out:
#                     상호명  지점명 상권업종대분류명 상권업종중분류명 상권업종소분류명    시도명  시군구명  \
# 1658            미래교육평가원  NaN       교육    기타 교육   컴퓨터 학원  서울특별시  영등포구
# 2790    송파컴퓨터회계학원시험장개설용  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   송파구
# 3978           싱크탱크에듀학원  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   성북구
# 17308             일렉트릭펀  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   금천구
# 21468         라움게임그래픽학원  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   강남구
# ...                 ...  ...      ...      ...      ...    ...   ...
# 524221        룩스디자인1212  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   마포구
# 529815           코드랩이앤티  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   금천구
# 533304         케이지아이티뱅크  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   종로구
# 533632          새로움코딩학원  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   송파구
# 534810           악어코딩학원  NaN       교육    기타 교육   컴퓨터 학원  서울특별시   강남구
#
#                        도로명                    도로명주소          경도         위도
# ...

# %%
shop_edu_etc_computer.shape
# Out:
# (302, 11)

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(data=shop_edu_etc_computer, x='경도', y='위도', hue='상권업종소분류명')
# Out:
# <Axes: xlabel='경도', ylabel='위도'>
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %% [markdown]
# #**3. Folium**
# [Folium](https://python-visualization.github.io/folium/latest)은 파이썬에서 대화형 지도(interactive map)를 생성할 수 있는 라이브러리입니다. 특히, 지리 데이터(Geospatial Data) 시각화에 최적화되어 있으며, 간단한 코드로 복잡한 지도 기능을 구현할 수 있도록 도와줍니다.

# %%
# 데이터를 지도에다가 깔아서 알아보기 쉽게

# %%
# !pip install folium

# %%
import folium

# %%
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)

map_folium
# folium.Map:지도를 뿌림
# 이 지도가 어디를 가르켜야하나?  location=[37.56652479270633, 126.9779129116262] 어디를 중심으로 줄 것인가
# zoom_start=15 어느정도 확대해서 보여줄 것인가
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)

popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup).add_to(map_folium)

map_folium

#folium.Popup : 우리가 어떤 마커를 하나 만들어서 거기에다가 표시를 해줬을 때, 그것을 클릭하면 나오는 글자가 팝업
#max_width=200 : 옆으로 길이 200
# folium.Marker: 그 팝업을 어디다 할지/Marker:핀찍는거
# popup=popup: 위도,경도 위치에다가 클릭하면 팝업이 뜨도록 해준다
# add_to(map_folium): 지도에다가 add해준 것 지도에다가 더해준것
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup).add_to(map_folium)

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

popup = folium.Popup('영풍문고-종로본점', max_width=200)
folium.Marker(location=[37.56999947440024, 126.98228391170936], popup=popup).add_to(map_folium)

map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
from folium.features import CustomIcon  #마커의 모양을 바꿀때 사용

icon = CustomIcon('police.png', icon_size=(32, 32))  #CustomIcon를 통해서 이미지를 가져오라는 의미

map_folium = folium.Map(location=[37.56652479270633, 126.9779129116262], zoom_start=15)
popup = folium.Popup('서울특별시청', max_width=200)
folium.Marker(location=[37.56652479270633, 126.9779129116262], popup=popup,
              icon=folium.Icon(icon='star', color='red')).add_to(map_folium) #icon='star', color='red

popup = folium.Popup('덕수궁', max_width=200)
folium.Marker(location=[37.56585320879458, 126.97514572197248], popup=popup,
              icon=folium.Icon(icon='ok', color='pink')).add_to(map_folium)

popup = folium.Popup('서울지방경찰청', max_width=200)
folium.Marker(location=[37.57504045678939, 126.97195576938117], popup=popup,
              icon=icon).add_to(map_folium)

popup = folium.Popup('광화문', max_width=200)
folium.Marker(location=[37.57617987638928, 126.97694467807803], popup=popup).add_to(map_folium)

# CircleMarker(): 원의 범위를 마커로 설정/ 원으로 그려지는 마커
popup = folium.Popup('내땅', max_width=200)
folium.CircleMarker(location=[37.56999947440024, 126.98228391170936], popup=popup,
              radius=30, color='red', fill_color='#ec4074').add_to(map_folium) #fill_color안에 채워지는 색상 # radius=30 반지름


map_folium
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
data = shop_edu_etc_computer

edu_map = folium.Map(location=[data['위도'].mean(), data['경도'].mean()], zoom_start=12)
#['위도'].mean() 위도 경도의 평균을 내면 중심점이 되니까 그 중심으로 지도를 보여주면 전체적인 데이터를 가운데서 볼 수 있다

for i in data.index:  # 데이터 인덱스의 개수만큼 반복
    edu_name = data.loc[i, '상호명'] + ' - ' + data.loc[i, '도로명주소'] #??????????????????????????????????
    # print(edu_name)
    popup = folium.Popup(edu_name, max_width=500) #팝업크기
    folium.Marker(location=[data.loc[i, '위도'], data.loc[i, '경도']],
                  popup=popup).add_to(edu_map)

edu_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
